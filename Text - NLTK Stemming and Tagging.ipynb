# %% [markdown]
# # Stemming and Part of Speech Tagging with NLTK
# ## 1. stemming
# ## 2. POS tagging

# %% [markdown]
# Concerning frequency distributions to utilize stemming and part of speech (POS) taggers.
#
# Stemming is the process for reducing words to their word stem, base or root form. For example, the result of stemming the words “kicker,” “kicked” and “kicking” is “kick.”
#
# The process of classifying words into their parts of speech and labeling them accordingly is known as part-of-speech tagging, POS-tagging, or simply tagging. Parts of speech are also known as word classes or lexical categories. The collection of tags used for a particular task is known as a tagset.
#
# A part-of-speech tagger, or POS-tagger, processes a sequence of words, and attaches a part of speech tag to each word.

# %% [markdown]
# # Preliminary Steps

# %%
import numpy as np
import pandas as pd
import nltk 
from nltk.corpus import stopwords
from nltk import FreqDist

# %%
df=pd.read_csv('100-200.csv', sep = ",")['body']
df.to_csv('test.csv') #save a dataframe only include the review body
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.

# %%
f = open('test.csv','r')
raw = f.read()

#raw = raw.replace('\n',' ',',')
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/isabelleliu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/isabelleliu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#Tokenization
tokens = nltk.word_tokenize(raw)

#Stopwords Removal and only keep text data then change to lowercase
mystopwords = stopwords.words('english')
words = [w.lower() for w in tokens if w.isalpha() if w.lower() not in mystopwords]

# %%
len(tokens)
# Out:
# 226000

# %%
len(words)
# Out:
# 91953

# %%
words
# Out:
# ['well',
#  'designed',
#  'great',
#  'looking',
#  'great',
#  'functioning',
#  'printer',
#  'except',
#  'specific',
#  'way',
#  'people',
#  'use',
#  'days',
#  'print',
#  'much',
#  'scan',
#  'lot',
#  'scan',
#  'scan',
#  'printer',
#  'direct',
#  'computer',
#  'go',
#  'back',
#  'computer',
#  'organize',
#  'scanned',
#  'printer',
#  'functionality',
#  'macs',
#  'yet',
#  'workaround',
#  'scan',
#  'email',
#  'convoluted',
#  'clumsy',
#  'use',
#  'mobile',
#  'app',
#  'less',
#  'convoluted',
#  'clumsy',
#  'still',
#  'aggravating',
#  'new',
#  'top',
#  'line',
#  'models',
#  'basic',
#  'functionality',
#  'way',
#  'people',
#  'work',
#  'today',
#  'printer',
#  'near',
#  'computer',
#  'need',
#  'anymore',
#  'like',
#  'able',
#  'scan',
#  'printer',
#  'searching',
#  'online',
#  'chatting',
#  'hp',
#  'support',
#  'finally',
#  'spoke',
#  'someone',
#  'going',
#  'terrible',
#  'automated',
#  'customer',
#  'service',
#  'line',
#  'said',
#  'functionality',
#  'come',
#  'finished',
#  'software',
#  'yet',
#  'know',
#  'day',
#  'need',
#  'scan',
#  'printer',
#  'direct',
#  'mac',
#  'want',
#  'clumsy',
#  'workaround',
#  'buy',
#  'update',
#  'review',
#  'hp',
#  'updates',
#  'software',
#  'printer',
#  'really',
#  'small',
#  'lots',
#  'features',
#  'really',
#  'lot',
#  'space',
#  'office',
#  'printer',
#  'fits',
#  'perfectly',
#  'plugged',
#  'computer',
#  'windows',
#  'detected',
#  'installed',
#  'required',
#  'drivers',
#  'automatically',
#  'could',
#  'printed',
#  'pages',
#  'time',
#  'tell',
#  'print',
#  'quality',
#  'excellent',
#  'quiet',
#  'printing',
#  'also',
#  'able',
#  'connect',
#  'smartphone',
#  'samsung',
#  'galaxy',
#  'print',
#  'document',
#  'phone',
#  'directly',
#  'cool',
#  'printer',
#  'came',
#  'cartridges',
#  'scanned',
#  'postcard',
#  'photos',
#  'omg',
#  'scanned',
#  'photos',
#  'look',
#  'better',
#  'original',
#  'printed',
#  'photo',
#  'looking',
#  'good',
#  'scanner',
#  'convert',
#  'old',
#  'photos',
#  'digital',
#  'know',
#  'weekend',
#  'btw',
#  'unlike',
#  'old',
#  'scanner',
#  'take',
#  'lot',
#  'time',
#  'took',
#  'may',
#  'seconds',
#  'scan',
#  'photo',
#  'fairly',
#  'quick',
#  'yet',
#  'try',
#  'features',
#  'already',
#  'blown',
#  'away',
#  'printer',
#  'continue',
#  'explore',
#  'update',
#  'review',
#  'far',
#  'favorite',
#  'feature',
#  'mobile',
#  'printing',
#  'buy',
#  'printer',
#  'second',
#  'canon',
#  'became',
#  'brick',
#  'less',
#  'years',
#  'research',
#  'find',
#  'best',
#  'one',
#  'price',
#  'point',
#  'bought',
#  'hp',
#  'hp',
#  'printers',
#  'years',
#  'always',
#  'happy',
#  'print',
#  'quality',
#  'stopped',
#  'buying',
#  'software',
#  'stupid',
#  'thankfully',
#  'addressed',
#  'fourth',
#  'time',
#  'updated',
#  'review',
#  'started',
#  'went',
#  'went',
#  'yeow',
#  'back',
#  'rating',
#  'due',
#  'significant',
#  'network',
#  'instability',
#  'everything',
#  'else',
#  'network',
#  'seemed',
#  'work',
#  'fine',
#  'new',
#  'tplink',
#  'wireless',
#  'router',
#  'except',
#  'printer',
#  'shortly',
#  'giving',
#  'printer',
#  'rating',
#  'detected',
#  'weird',
#  'happenings',
#  'router',
#  'talking',
#  'tech',
#  'support',
#  'changes',
#  'router',
#  'worked',
#  'much',
#  'better',
#  'amazingly',
#  'printer',
#  'lost',
#  'connection',
#  'since',
#  'print',
#  'quality',
#  'speed',
#  'great',
#  'works',
#  'equally',
#  'fine',
#  'linux',
#  'ipad',
#  'feature',
#  'started',
#  'using',
#  'document',
#  'feeder',
#  'first',
#  'home',
#  'printer',
#  'sure',
#  'beats',
#  'page',
#  'scan',
#  'standing',
#  'printer',
#  'issue',
#  'feed',
#  'scanner',
#  'slightly',
#  'ajar',
#  'checked',
#  'option',
#  'align',
#  'scan',
#  'seem',
#  'help',
#  'still',
#  'put',
#  'minimally',
#  'wonky',
#  'scans',
#  'manually',
#  'feed',
#  'feeder',
#  'also',
#  'works',
#  'copies',
#  'security',
#  'concerns',
#  'sure',
#  'thinking',
#  'designed',
#  'printer',
#  'wifi',
#  'addition',
#  'connecting',
#  'wifi',
#  'like',
#  'circumventing',
#  'security',
#  'need',
#  'wifi',
#  'whatever',
#  'purposes',
#  'serves',
#  'big',
#  'complaint',
#  'simple',
#  'printer',
#  'setup',
#  'go',
#  'find',
#  'turn',
#  'second',
#  'concern',
#  'send',
#  'technical',
#  'diagnostic',
#  'info',
#  'back',
#  'hp',
#  'say',
#  'identifying',
#  'information',
#  'care',
#  'want',
#  'info',
#  'leaving',
#  'network',
#  'unless',
#  'initiate',
#  'simple',
#  'printer',
#  'setup',
#  'go',
#  'find',
#  'really',
#  'hp',
#  'issue',
#  'hp',
#  'iphone',
#  'app',
#  'setup',
#  'allowed',
#  'printer',
#  'pull',
#  'networks',
#  'ssid',
#  'password',
#  'iphone',
#  'store',
#  'printer',
#  'idea',
#  'app',
#  'iphone',
#  'could',
#  'get',
#  'network',
#  'info',
#  'thought',
#  'info',
#  'iphone',
#  'settings',
#  'used',
#  'connect',
#  'network',
#  'apps',
#  'thinking',
#  'guess',
#  'hp',
#  'iphone',
#  'app',
#  'connected',
#  'proprietary',
#  'wifi',
#  'hp',
#  'printer',
#  'initial',
#  'connection',
#  'set',
#  'home',
#  'wifi',
#  'info',
#  'fair',
#  'enough',
#  'point',
#  'hp',
#  'proprietary',
#  'network',
#  'disappear',
#  'simple',
#  'prompt',
#  'work',
#  'home',
#  'person',
#  'well',
#  'mom',
#  'high',
#  'schooler',
#  'third',
#  'grader',
#  'need',
#  'reliable',
#  'printer',
#  'hp',
#  'never',
#  'failed',
#  'gets',
#  'better',
#  'better',
#  'new',
#  'printer',
#  'officejet',
#  'pro',
#  'nicely',
#  'designed',
#  'printer',
#  'bulky',
#  'works',
#  'perfectly',
#  'needs',
#  'setup',
#  'breeze',
#  'plug',
#  'outlet',
#  'turn',
#  'install',
#  'ink',
#  'load',
#  'paper',
#  'go',
#  'printer',
#  'software',
#  'download',
#  'page',
#  'straight',
#  'forward',
#  'easy',
#  'touch',
#  'screen',
#  'great',
#  'size',
#  'bright',
#  'easy',
#  'use',
#  'printing',
#  'quick',
#  'quiet',
#  'great',
#  'quality',
#  'scanning',
#  'copying',
#  'faxing',
#  'work',
#  'perfectly',
#  'smart',
#  'app',
#  'far',
#  'best',
#  'easiest',
#  'app',
#  'used',
#  'printer',
#  'view',
#  'everything',
#  'need',
#  'know',
#  'printer',
#  'even',
#  'see',
#  'instant',
#  'ink',
#  'information',
#  'setup',
#  'use',
#  'three',
#  'laptops',
#  'two',
#  'iphones',
#  'ipad',
#  'work',
#  'great',
#  'even',
#  'love',
#  'print',
#  'anywhere',
#  'option',
#  'smart',
#  'app',
#  'definitely',
#  'comes',
#  'handy',
#  'instant',
#  'ink',
#  'user',
#  'awhile',
#  'highly',
#  'recommend',
#  'saved',
#  'much',
#  'money',
#  'replacing',
#  'printer',
#  'account',
#  'easy',
#  'best',
#  'rollover',
#  'pages',
#  'transferred',
#  'plus',
#  'got',
#  'extra',
#  'months',
#  'free',
#  'instant',
#  'ink',
#  'wanted',
#  'like',
#  'printer',
#  'keeps',
#  'dropping',
#  'wifi',
#  'connection',
#  'goes',
#  'ca',
#  'print',
#  'supposed',
#  'wifi',
#  'either',
#  'way',
#  'year',
#  'old',
#  'epson',
#  'never',
#  'dropped',
#  'connection',
#  'devices',
#  'house',
#  'dropping',
#  'brand',
#  'new',
#  'hp',
#  'printer',
#  'got',
#  'setup',
#  'running',
#  'tested',
#  'great',
#  'tested',
#  'great',
#  'tested',
#  'macbook',
#  'followed',
#  'instructions',
#  'downloaded',
#  'driver',
#  'connected',
#  'wifi',
#  'still',
#  'work',
#  'properly',
#  'would',
#  'send',
#  'info',
#  'printer',
#  'would',
#  'recognize',
#  'minutes',
#  'started',
#  'printing',
#  'snail',
#  'pace',
#  'would',
#  'print',
#  'last',
#  'page',
#  'spit',
#  'rest',
#  'paper',
#  'called',
#  'support',
#  'let',
#  'remotely',
#  'control',
#  'computer',
#  'try',
#  'change',
#  'settings',
#  'half',
#  'hour',
#  'dinking',
#  'around',
#  'computer',
#  'came',
#  'conclusion',
#  'printer',
#  'faulty',
#  'pissed',
#  'said',
#  'could',
#  'driver',
#  'sent',
#  'replacement',
#  'update',
#  'review',
#  'get',
#  'setup',
#  'try',
#  'everything',
#  'else',
#  'great',
#  'print',
#  'works',
#  'great',
#  'turns',
#  'would',
#  'work',
#  'connected',
#  'instead',
#  'know',
#  'first',
#  'printer',
#  'ever',
#  'bought',
#  'know',
#  'guess',
#  'great',
#  'printer',
#  'purchased',
#  'printer',
#  'thinking',
#  'print',
#  'quality',
#  'would',
#  'good',
#  'big',
#  'mistake',
#  'colors',
#  'cloudy',
#  'images',
#  'crisp',
#  'clean',
#  'bit',
#  'fuzzy',
#  'side',
#  'purchasing',
#  'amazon',
#  'royal',
#  'pain',
#  'return',
#  'printer',
#  'gone',
#  'best',
#  'buy',
#  'would',
#  'preferred',
#  'give',
#  'stars',
#  'rating',
#  'hp',
#  'one',
#  'says',
#  'print',
#  'quality',
#  'outstanding',
#  'scanning',
#  'documents',
#  'excellent',
#  'faxing',
#  'emailing',
#  'documents',
#  'superb',
#  'direct',
#  'printing',
#  'smartphones',
#  'simplistic',
#  'set',
#  'printer',
#  'set',
#  'network',
#  'breeze',
#  'less',
#  'minutes',
#  'price',
#  'could',
#  'pass',
#  'well',
#  'worth',
#  'edit',
#  'sent',
#  'back',
#  'save',
#  'money',
#  'buy',
#  'different',
#  'brand',
#  'purchased',
#  'hp',
#  'life',
#  'recently',
#  'series',
#  'years',
#  'finally',
#  'died',
#  'printer',
#  'cheaply',
#  'made',
#  'paper',
#  'tray',
#  'flimsy',
#  'little',
#  'plastic',
#  'prongs',
#  'shift',
#  'paper',
#  'upwards',
#  'every',
#  'time',
#  'print',
#  'sucks',
#  'multiple',
#  'pages',
#  'ink',
#  'spread',
#  'across',
#  'pages',
#  'know',
#  'happened',
#  'hp',
#  'definitely',
#  'went',
#  'downhill',
#  'print',
#  'quality',
#  'fuzzy',
#  'even',
#  'tried',
#  'second',
#  'time',
#  'alignment',
#  'never',
#  'correct',
#  'print',
#  'every',
#  'time',
#  'prints',
#  'across',
#  'multiple',
#  'sheets',
#  'paper',
#  'would',
#  'give',
#  'less',
#  'one',
#  'rating',
#  'old',
#  'lexmark',
#  'printer',
#  'absolutely',
#  'loved',
#  'print',
#  'quality',
#  'outstanding',
#  'used',
#  'everything',
#  'printing',
#  'college',
#  'term',
#  'papers',
#  'business',
#  'documents',
#  'printing',
#  'artwork',
#  'photos',
#  'spite',
#  'age',
#  'bought',
#  'nearly',
#  'years',
#  'ago',
#  'real',
#  'workhorse',
#  'kept',
#  'right',
#  'going',
#  'matter',
#  'much',
#  'threw',
#  'fact',
#  'get',
#  'rid',
#  'still',
#  'worked',
#  'problem',
#  'printer',
#  'problem',
#  'lexmark',
#  'company',
#  'apparently',
#  'decided',
#  'get',
#  'printer',
#  'business',
#  'late',
#  'could',
#  'longer',
#  'buy',
#  'ink',
#  'cartridges',
#  'particular',
#  'lexmark',
#  'model',
#  'thus',
#  'search',
#  'new',
#  'printer',
#  'begin',
#  'thus',
#  'enter',
#  'beauty',
#  'hp',
#  'officejet',
#  'pro',
#  'got',
#  'ta',
#  'honest',
#  'gon',
#  'na',
#  'miss',
#  'lexmark',
#  'print',
#  'quality',
#  'hp',
#  'officejet',
#  'pro',
#  'every',
#  'bit',
#  'good',
#  'former',
#  'beloved',
#  'printer',
#  'fact',
#  'despite',
#  'hp',
#  'early',
#  'intimations',
#  'printer',
#  'considered',
#  'photo',
#  'printer',
#  'actually',
#  'beautiful',
#  'job',
#  'printing',
#  'photos',
#  'photo',
#  'paper',
#  'regular',
#  'paper',
#  'addition',
#  'printing',
#  'officejet',
#  'pro',
#  'also',
#  'scan',
#  'function',
#  'copy',
#  'machine',
#  'send',
#  'faxes',
#  'landline',
#  'unlike',
#  'old',
#  'lexmark',
#  'officejet',
#  'pro',
#  'offers',
#  'multiple',
#  'means',
#  'connectivity',
#  'addition',
#  'single',
#  'computer',
#  'hp',
#  'printer',
#  'also',
#  'shared',
#  'via',
#  'bluetooth',
#  'ethernet',
#  'outstanding',
#  'print',
#  'quality',
#  'three',
#  'things',
#  'really',
#  'like',
#  'hp',
#  'officejet',
#  'pro',
#  'first',
#  'setup',
#  'easy',
#  'pie',
#  'turn',
#  'printer',
#  'install',
#  'ink',
#  'cartridges',
#  'connect',
#  'printer',
#  'computer',
#  'voilà',
#  'printer',
#  'drivers',
#  'immediately',
#  'downloaded',
#  'installed',
#  'snap',
#  'truly',
#  'device',
#  'must',
#  'also',
#  'note',
#  'even',
#  'though',
#  'printer',
#  'scanner',
#  'scanner',
#  'drivers',
#  'interfere',
#  'drivers',
#  'functionality',
#  'canon',
#  'scanner',
#  'need',
#  'professional',
#  'art',
#  'photography',
#  'projects',
#  'even',
#  'installation',
#  'hp',
#  'software',
#  'presumptuous',
#  'never',
#  'assumed',
#  'wanted',
#  'hp',
#  'scanner',
#  'become',
#  'default',
#  'secondly',
#  'separate',
#  'ink',
#  'cartridges',
#  'color',
#  'opposed',
#  'common',
#  'practice',
#  'three',
#  'primary',
#  'colors',
#  'combined',
#  'single',
#  'cartridge',
#  'means',
#  'use',
#  'lot',
#  'one',
#  'color',
#  'say',
#  'cyan',
#  ...]

# %% [markdown]
# # Stemming

# %% [markdown]
# ## 1. Porter Stemmer

# %%
#Use Porter Stemmer 
porter = nltk.PorterStemmer()
stem1 = [porter.stem(w) for w in words]

#Get the frequency distribution 
freq1 = FreqDist(stem1)
#Sort the result
sorted_freq1 = sorted(freq1.items(),key = lambda k: k[1], reverse = True)
sorted_freq1
# Out:
# [('printer', 4248),
#  ('print', 3083),
#  ('use', 1379),
#  ('ink', 1330),
#  ('work', 1297),
#  ('paper', 917),
#  ('set', 907),
#  ('hp', 896),
#  ('one', 865),
#  ('great', 827),
#  ('easi', 813),
#  ('canon', 723),
#  ('get', 721),
#  ('good', 702),
#  ('qualiti', 689),
#  ('time', 671),
#  ('cartridg', 619),
#  ('like', 609),
#  ('would', 595),
#  ('scan', 559),
#  ('connect', 542),
#  ('need', 516),
#  ('photo', 465),
#  ('page', 450),
#  ('tri', 441),
#  ('buy', 426),
#  ('wireless', 389),
#  ('well', 384),
#  ('love', 378),
#  ('price', 376),
#  ('replac', 372),
#  ('even', 365),
#  ('go', 359),
#  ('instal', 357),
#  ('comput', 354),
#  ('tray', 348),
#  ('color', 346),
#  ('also', 345),
#  ('problem', 344),
#  ('setup', 325),
#  ('product', 306),
#  ('issu', 302),
#  ('far', 299),
#  ('back', 298),
#  ('look', 296),
#  ('home', 296),
#  ('support', 293),
#  ('phone', 293),
#  ('new', 289),
#  ('want', 287),
#  ('make', 286),
#  ('year', 283),
#  ('thing', 283),
#  ('document', 279),
#  ('could', 278),
#  ('month', 277),
#  ('purchas', 276),
#  ('realli', 275),
#  ('much', 264),
#  ('wifi', 263),
#  ('bought', 256),
#  ('first', 248),
#  ('nice', 247),
#  ('jam', 241),
#  ('copi', 238),
#  ('old', 237),
#  ('last', 231),
#  ('review', 229),
#  ('take', 227),
#  ('still', 225),
#  ('seem', 220),
#  ('littl', 219),
#  ('lot', 215),
#  ('app', 215),
#  ('error', 215),
#  ('featur', 212),
#  ('got', 211),
#  ('fast', 210),
#  ('softwar', 207),
#  ('recommend', 205),
#  ('day', 204),
#  ('say', 201),
#  ('never', 200),
#  ('screen', 199),
#  ('black', 195),
#  ('return', 192),
#  ('come', 191),
#  ('run', 189),
#  ('better', 187),
#  ('turn', 186),
#  ('everi', 186),
#  ('offic', 182),
#  ('anoth', 180),
#  ('network', 172),
#  ('hour', 169),
#  ('way', 168),
#  ('start', 167),
#  ('everyth', 167),
#  ('model', 166),
#  ('excel', 166),
#  ('scanner', 165),
#  ('two', 164),
#  ('small', 162),
#  ('ca', 162),
#  ('abl', 161),
#  ('happi', 161),
#  ('driver', 160),
#  ('tech', 160),
#  ('amazon', 158),
#  ('machin', 158),
#  ('instruct', 154),
#  ('long', 154),
#  ('without', 153),
#  ('fine', 152),
#  ('mani', 152),
#  ('right', 151),
#  ('find', 150),
#  ('fax', 150),
#  ('job', 149),
#  ('sinc', 147),
#  ('ever', 147),
#  ('order', 147),
#  ('size', 145),
#  ('box', 145),
#  ('someth', 143),
#  ('help', 142),
#  ('devic', 142),
#  ('function', 139),
#  ('cost', 138),
#  ('pretti', 138),
#  ('minut', 137),
#  ('download', 136),
#  ('took', 135),
#  ('give', 135),
#  ('think', 135),
#  ('know', 134),
#  ('call', 134),
#  ('money', 132),
#  ('less', 131),
#  ('side', 130),
#  ('sure', 128),
#  ('howev', 128),
#  ('see', 124),
#  ('laptop', 124),
#  ('messag', 124),
#  ('came', 123),
#  ('best', 123),
#  ('keep', 122),
#  ('expens', 122),
#  ('yet', 121),
#  ('window', 121),
#  ('manual', 121),
#  ('pictur', 121),
#  ('option', 120),
#  ('bit', 120),
#  ('touch', 119),
#  ('usb', 119),
#  ('includ', 118),
#  ('updat', 116),
#  ('reason', 116),
#  ('expect', 115),
#  ('alway', 114),
#  ('final', 111),
#  ('send', 110),
#  ('load', 110),
#  ('star', 110),
#  ('clear', 110),
#  ('anyth', 110),
#  ('slow', 110),
#  ('put', 109),
#  ('noth', 108),
#  ('made', 107),
#  ('disappoint', 107),
#  ('read', 107),
#  ('servic', 105),
#  ('though', 105),
#  ('simpl', 104),
#  ('stop', 103),
#  ('week', 102),
#  ('hard', 102),
#  ('automat', 101),
#  ('sever', 100),
#  ('open', 100),
#  ('brand', 99),
#  ('differ', 99),
#  ('hold', 98),
#  ('second', 96),
#  ('went', 95),
#  ('chang', 95),
#  ('plug', 94),
#  ('receiv', 94),
#  ('figur', 94),
#  ('enough', 93),
#  ('cheap', 93),
#  ('design', 92),
#  ('actual', 92),
#  ('complet', 92),
#  ('end', 92),
#  ('piec', 92),
#  ('user', 91),
#  ('perfect', 91),
#  ('instant', 90),
#  ('wo', 90),
#  ('quickli', 90),
#  ('epson', 89),
#  ('power', 89),
#  ('bad', 89),
#  ('low', 89),
#  ('own', 89),
#  ('high', 88),
#  ('save', 88),
#  ('via', 88),
#  ('found', 88),
#  ('feel', 88),
#  ('custom', 87),
#  ('quit', 87),
#  ('hope', 86),
#  ('avail', 86),
#  ('test', 85),
#  ('tell', 84),
#  ('cabl', 84),
#  ('fix', 84),
#  ('oper', 84),
#  ('sheet', 83),
#  ('easili', 83),
#  ('part', 83),
#  ('imag', 82),
#  ('multipl', 82),
#  ('top', 81),
#  ('frustrat', 80),
#  ('said', 79),
#  ('feed', 79),
#  ('follow', 79),
#  ('next', 79),
#  ('pleas', 79),
#  ('onlin', 78),
#  ('wast', 78),
#  ('done', 78),
#  ('process', 78),
#  ('speed', 77),
#  ('around', 77),
#  ('previou', 77),
#  ('pc', 77),
#  ('ship', 77),
#  ('iphon', 76),
#  ('decid', 75),
#  ('place', 75),
#  ('difficult', 75),
#  ('pro', 74),
#  ('feeder', 73),
#  ('longer', 73),
#  ('super', 73),
#  ('full', 73),
#  ('requir', 72),
#  ('unit', 72),
#  ('deal', 72),
#  ('remov', 72),
#  ('line', 71),
#  ('front', 71),
#  ('almost', 71),
#  ('router', 70),
#  ('big', 70),
#  ('allow', 70),
#  ('wish', 70),
#  ('pull', 69),
#  ('officejet', 69),
#  ('busi', 69),
#  ('coupl', 69),
#  ('overal', 69),
#  ('program', 69),
#  ('worst', 69),
#  ('pay', 69),
#  ('direct', 68),
#  ('sent', 68),
#  ('capabl', 68),
#  ('probabl', 68),
#  ('compact', 68),
#  ('toner', 68),
#  ('mac', 67),
#  ('may', 67),
#  ('quick', 67),
#  ('highli', 67),
#  ('past', 67),
#  ('panel', 67),
#  ('quiet', 66),
#  ('clean', 66),
#  ('code', 66),
#  ('away', 65),
#  ('let', 65),
#  ('worth', 65),
#  ('flimsi', 65),
#  ('kept', 65),
#  ('brother', 65),
#  ('constantli', 65),
#  ('older', 64),
#  ('wait', 64),
#  ('button', 64),
#  ('sometim', 64),
#  ('white', 64),
#  ('alreadi', 63),
#  ('fit', 62),
#  ('show', 62),
#  ('inkjet', 62),
#  ('troubl', 62),
#  ('card', 62),
#  ('cannon', 62),
#  ('point', 61),
#  ('either', 61),
#  ('ask', 61),
#  ('check', 60),
#  ('spent', 60),
#  ('stay', 60),
#  ('guess', 59),
#  ('number', 59),
#  ('ok', 59),
#  ('definit', 58),
#  ('goe', 58),
#  ('half', 58),
#  ('amaz', 58),
#  ('experi', 58),
#  ('plan', 58),
#  ('gener', 58),
#  ('happen', 57),
#  ('person', 57),
#  ('item', 57),
#  ('refil', 57),
#  ('laser', 57),
#  ('email', 56),
#  ('initi', 56),
#  ('thought', 56),
#  ('singl', 56),
#  ('mayb', 56),
#  ('space', 55),
#  ('free', 55),
#  ('bluetooth', 55),
#  ('although', 55),
#  ('head', 55),
#  ('compar', 55),
#  ('add', 55),
#  ('gave', 55),
#  ('absolut', 54),
#  ('beauti', 54),
#  ('total', 54),
#  ('websit', 54),
#  ('copier', 54),
#  ('move', 54),
#  ('hook', 54),
#  ('basic', 53),
#  ('fact', 53),
#  ('etc', 53),
#  ('pixma', 53),
#  ('provid', 53),
#  ('extrem', 53),
#  ('awesom', 53),
#  ('tank', 53),
#  ('annoy', 52),
#  ('list', 52),
#  ('per', 52),
#  ('text', 52),
#  ('peopl', 51),
#  ('three', 51),
#  ('plastic', 51),
#  ('room', 51),
#  ('cd', 51),
#  ('useless', 51),
#  ('align', 50),
#  ('instead', 50),
#  ('step', 50),
#  ('perform', 50),
#  ('close', 50),
#  ('fairli', 49),
#  ('light', 49),
#  ('internet', 49),
#  ('junk', 49),
#  ('duplex', 49),
#  ('output', 49),
#  ('system', 49),
#  ('arriv', 49),
#  ('rear', 49),
#  ('except', 48),
#  ('perfectli', 48),
#  ('origin', 48),
#  ('rate', 48),
#  ('els', 48),
#  ('ipad', 48),
#  ('smart', 48),
#  ('must', 48),
#  ('least', 48),
#  ('offer', 47),
#  ('type', 47),
#  ('decent', 47),
#  ('sign', 47),
#  ('mode', 47),
#  ('desk', 47),
#  ('directli', 46),
#  ('continu', 46),
#  ('control', 46),
#  ('told', 46),
#  ('larg', 46),
#  ('wirelessli', 46),
#  ('reliabl', 45),
#  ('ago', 45),
#  ('often', 45),
#  ('faster', 45),
#  ('life', 44),
#  ('later', 44),
#  ('upgrad', 44),
#  ('bottom', 44),
#  ('tablet', 44),
#  ('touchscreen', 44),
#  ('troubleshoot', 44),
#  ('display', 44),
#  ('thank', 43),
#  ('complaint', 43),
#  ('unless', 43),
#  ('properli', 43),
#  ('mean', 43),
#  ('might', 43),
#  ('rather', 43),
#  ('select', 43),
#  ('exactli', 43),
#  ('current', 43),
#  ('version', 43),
#  ('research', 42),
#  ('compani', 42),
#  ('especi', 42),
#  ('googl', 42),
#  ('us', 42),
#  ('result', 42),
#  ('rel', 42),
#  ('doubl', 42),
#  ('label', 42),
#  ('reinstal', 42),
#  ('mobil', 41),
#  ('fail', 41),
#  ('pain', 41),
#  ('jet', 41),
#  ('notic', 41),
#  ('impress', 41),
#  ('plain', 41),
#  ('valu', 41),
#  ('wire', 41),
#  ('drop', 40),
#  ('hous', 40),
#  ('die', 40),
#  ('miss', 40),
#  ('abil', 40),
#  ('smaller', 40),
#  ('easier', 40),
#  ('addit', 39),
#  ('care', 39),
#  ('other', 39),
#  ('x', 39),
#  ('kind', 39),
#  ('suppos', 38),
#  ('regular', 38),
#  ('level', 38),
#  ('contact', 38),
#  ('limit', 38),
#  ('adjust', 38),
#  ('usual', 38),
#  ('appl', 38),
#  ('understand', 38),
#  ('shut', 38),
#  ('appear', 38),
#  ('spend', 38),
#  ('advertis', 38),
#  ('cord', 38),
#  ('garbag', 38),
#  ('warranti', 38),
#  ('disc', 38),
#  ('today', 37),
#  ('recogn', 37),
#  ('desktop', 37),
#  ('warn', 37),
#  ('cheaper', 37),
#  ('sit', 37),
#  ('within', 37),
#  ('finish', 36),
#  ('plu', 36),
#  ('access', 36),
#  ('hate', 36),
#  ('file', 36),
#  ('resolv', 36),
#  ('wonder', 36),
#  ('wrong', 36),
#  ('terribl', 35),
#  ('inform', 35),
#  ('extra', 35),
#  ('consid', 35),
#  ('default', 35),
#  ('paid', 35),
#  ('normal', 35),
#  ('restart', 35),
#  ('horribl', 35),
#  ('pack', 35),
#  ('real', 34),
#  ('despit', 34),
#  ('ethernet', 34),
#  ('anyon', 34),
#  ('whole', 34),
#  ('standard', 34),
#  ('poor', 34),
#  ('eas', 34),
#  ('surpris', 34),
#  ('store', 33),
#  ('report', 33),
#  ('cours', 33),
#  ('simpli', 33),
#  ('packag', 33),
#  ('insert', 33),
#  ('ye', 33),
#  ('accept', 33),
#  ('menu', 33),
#  ('regist', 33),
#  ('due', 32),
#  ('breez', 32),
#  ('prefer', 32),
#  ('conveni', 32),
#  ('base', 32),
#  ('frequent', 32),
#  ('otherwis', 32),
#  ('sell', 32),
#  ('cloud', 32),
#  ('broken', 32),
#  ('search', 31),
#  ('anywher', 31),
#  ('gone', 31),
#  ('seri', 31),
#  ('wife', 31),
#  ('school', 31),
#  ('w', 31),
#  ('site', 31),
#  ('suggest', 31),
#  ('compat', 31),
#  ('push', 31),
#  ('satisfi', 31),
#  ('readi', 31),
#  ('choic', 31),
#  ('friendli', 31),
#  ('broke', 31),
#  ('forev', 31),
#  ('airprint', 31),
#  ('state', 31),
#  ('someon', 30),
#  ('crisp', 30),
#  ('correct', 30),
#  ('main', 30),
#  ('hit', 30),
#  ('click', 30),
#  ('stuff', 30),
#  ('footprint', 30),
#  ('drive', 30),
#  ('unplug', 30),
#  ('possibl', 30),
#  ('six', 30),
#  ('visitor', 30),
#  ('talk', 29),
#  ('reset', 29),
#  ('complic', 29),
#  ('caus', 29),
#  ('cover', 29),
#  ('interfac', 29),
#  ('break', 29),
#  ('neg', 29),
#  ('confus', 29),
#  ('leav', 28),
#  ('third', 28),
#  ('thu', 28),
#  ('afford', 28),
#  ('crap', 28),
#  ('name', 28),
#  ('stuck', 28),
#  ('auto', 28),
#  ('soon', 28),
#  ('fantast', 28),
#  ('wake', 28),
#  ('correctli', 28),
#  ('offlin', 28),
#  ('charg', 28),
#  ('respons', 28),
#  ('idea', 27),
#  ('account', 27),
#  ('recent', 27),
#  ('matter', 27),
#  ('profession', 27),
#  ('live', 27),
#  ('pop', 27),
#  ('huge', 27),
#  ('b', 27),
#  ('hand', 27),
#  ('none', 27),
#  ('mine', 27),
#  ('aw', 27),
#  ('parti', 27),
#  ('attempt', 27),
#  ('attach', 27),
#  ('sleep', 27),
#  ('amount', 27),
#  ('photograph', 27),
#  ('suck', 26),
#  ('true', 26),
#  ('case', 26),
#  ('famili', 26),
#  ('produc', 26),
#  ('liter', 26),
#  ('occasion', 26),
#  ('realiz', 26),
#  ('play', 26),
#  ('blue', 26),
#  ('success', 26),
#  ('switch', 26),
#  ('usag', 26),
#  ('purpos', 25),
#  ('rang', 25),
#  ('pick', 25),
#  ('major', 25),
#  ('volum', 25),
#  ('glad', 25),
#  ('forc', 25),
#  ('chose', 25),
#  ('twice', 25),
#  ('suppli', 25),
#  ('pdf', 25),
#  ('dri', 25),
#  ('saw', 25),
#  ('xl', 25),
#  ('zero', 25),
#  ('period', 25),
#  ('posit', 25),
#  ('firmwar', 25),
#  ('immedi', 24),
#  ('disconnect', 24),
#  ('onto', 24),
#  ('built', 24),
#  ('manufactur', 24),
#  ('descript', 24),
#  ('envelop', 24),
#  ('world', 24),
#  ('indic', 24),
#  ('market', 24),
#  ('lack', 24),
#  ('local', 24),
#  ('password', 23),
#  ('separ', 23),
#  ('locat', 23),
#  ('okay', 23),
#  ('anyway', 23),
#  ('ridicul', 23),
#  ('import', 23),
#  ('left', 23),
#  ('describ', 23),
#  ('ad', 23),
#  ('subscript', 23),
#  ('effici', 23),
#  ('stick', 23),
#  ('respond', 23),
#  ('cell', 23),
#  ('speak', 23),
#  ('mention', 23),
#  ('smartphon', 22),
#  ('remot', 22),
#  ('nearli', 22),
#  ('appar', 22),
#  ('note', 22),
#  ('ran', 22),
#  ('learn', 22),
#  ('commun', 22),
#  ('enjoy', 22),
#  ('word', 22),
#  ('given', 22),
#  ('mess', 22),
#  ('believ', 22),
#  ('throw', 22),
#  ('short', 22),
#  ('handl', 22),
#  ('extend', 22),
#  ('averag', 22),
#  ('press', 22),
#  ('min', 22),
#  ('sale', 22),
#  ('higher', 22),
#  ('android', 22),
#  ('intuit', 22),
#  ('anymor', 21),
#  ('address', 21),
#  ('air', 21),
#  ('solid', 21),
#  ('chanc', 21),
#  ('seen', 21),
#  ('imposs', 21),
#  ('husband', 21),
#  ('area', 21),
#  ('letter', 21),
#  ('question', 21),
#  ('bare', 21),
#  ('manag', 21),
#  ('technolog', 21),
#  ('mostli', 21),
#  ('defect', 21),
#  ('consum', 21),
#  ('technic', 20),
#  ('info', 20),
#  ('outstand', 20),
#  ('along', 20),
#  ('minor', 20),
#  ('unabl', 20),
#  ('kid', 20),
#  ('friend', 20),
#  ('reconnect', 20),
#  ('catch', 20),
#  ('slide', 20),
#  ('lan', 20),
#  ('cancel', 20),
#  ('blank', 20),
#  ('dont', 20),
#  ('entir', 20),
#  ('inexpens', 20),
#  ('trash', 20),
#  ('slower', 20),
#  ('unfortun', 20),
#  ('worri', 20),
#  ('constant', 20),
#  ('empti', 20),
#  ('retract', 20),
#  ('chat', 19),
#  ('detect', 19),
#  ('macbook', 19),
#  ('practic', 19),
#  ('choos', 19),
#  ('wors', 19),
#  ('luck', 19),
#  ('creat', 19),
#  ('discov', 19),
#  ('sharp', 19),
#  ('sleek', 19),
#  ('opt', 19),
#  ('flawlessli', 19),
#  ('five', 19),
#  ('improv', 19),
#  ('daili', 19),
#  ('four', 19),
#  ('cumbersom', 19),
#  ('slot', 19),
#  ('camera', 19),
#  ('concern', 18),
#  ('easiest', 18),
#  ('term', 18),
#  ('project', 18),
#  ('refund', 18),
#  ('signal', 18),
#  ('rare', 18),
#  ('deliveri', 18),
#  ('crazi', 18),
#  ('mind', 18),
#  ('newer', 18),
#  ('navig', 18),
#  ('write', 18),
#  ('previous', 18),
#  ('similar', 18),
#  ('sampl', 18),
#  ('detail', 18),
#  ('sound', 18),
#  ('media', 18),
#  ('amira', 18),
#  ('specif', 17),
#  ('stand', 17),
#  ('whatev', 17),
#  ('straight', 17),
#  ('bright', 17),
#  ('mistak', 17),
#  ('cheapli', 17),
#  ('across', 17),
#  ('late', 17),
#  ('begin', 17),
#  ('port', 17),
#  ('larger', 17),
#  ('lose', 17),
#  ('beyond', 17),
#  ('incred', 17),
#  ('biggest', 17),
#  ('comment', 17),
#  ('configur', 17),
#  ('unreli', 17),
#  ('task', 17),
#  ('draft', 17),
#  ('resolut', 17),
#  ('dislik', 17),
#  ('doc', 17),
#  ('rememb', 17),
#  ('odd', 17),
#  ('glossi', 17),
#  ('prepar', 17),
#  ('lost', 16),
#  ('prompt', 16),
#  ('becom', 16),
#  ('materi', 16),
#  ('assist', 16),
#  ('dell', 16),
#  ('student', 16),
#  ('thru', 16),
#  ('noisi', 16),
#  ('solut', 16),
#  ('eventu', 16),
#  ('os', 16),
#  ('web', 16),
#  ('excit', 16),
#  ('starter', 16),
#  ('delet', 16),
#  ('envi', 16),
#  ('serious', 16),
#  ('engin', 16),
#  ('charm', 16),
#  ('hassl', 16),
#  ('con', 16),
#  ('ton', 16),
#  ('variou', 16),
#  ('chromebook', 16),
#  ('nois', 16),
#  ('deliv', 16),
#  ('oh', 16),
#  ('finger', 16),
#  ('dvd', 16),
#  ('cool', 15),
#  ('secur', 15),
#  ('assum', 15),
#  ('magenta', 15),
#  ('fulli', 15),
#  ('spot', 15),
#  ('walk', 15),
#  ('opinion', 15),
#  ('honestli', 15),
#  ('latest', 15),
#  ('refus', 15),
#  ('lift', 15),
#  ('bigger', 15),
#  ('physic', 15),
#  ('applic', 15),
#  ('prior', 15),
#  ('util', 15),
#  ('format', 15),
#  ('experienc', 15),
#  ('numer', 15),
#  ('shoot', 15),
#  ('door', 15),
#  ('nightmar', 15),
#  ('monthli', 15),
#  ('book', 15),
#  ('insid', 15),
#  ('electron', 15),
#  ('adf', 15),
#  ('fan', 15),
#  ('reboot', 15),
#  ('io', 15),
#  ('gift', 15),
#  ('whether', 15),
#  ('special', 15),
#  ('mainli', 15),
#  ('repair', 15),
#  ('near', 14),
#  ('slightli', 14),
#  ('minim', 14),
#  ('fair', 14),
#  ('awhil', 14),
#  ('multifunct', 14),
#  ('doubt', 14),
#  ('virtual', 14),
#  ('taken', 14),
#  ('mark', 14),
#  ('knew', 14),
#  ('everyon', 14),
#  ('guy', 14),
#  ('alon', 14),
#  ('match', 14),
#  ('flip', 14),
#  ('struggl', 14),
#  ('futur', 14),
#  ('tini', 14),
#  ('mechan', 14),
#  ('storag', 14),
#  ('damag', 14),
#  ('cycl', 14),
#  ('avoid', 14),
#  ('claim', 14),
#  ('depend', 14),
#  ('cart', 14),
#  ('floor', 14),
#  ('attract', 14),
#  ('headach', 14),
#  ('uninstal', 14),
#  ('smoothli', 14),
#  ('pic', 14),
#  ('pair', 14),
#  ('upon', 14),
#  ('lower', 14),
#  ('appli', 14),
#  ('inch', 14),
#  ('stupid', 13),
#  ('weird', 13),
#  ('enter', 13),
#  ('truli', 13),
#  ('cyan', 13),
#  ('worthless', 13),
#  ('middl', 13),
#  ('consist', 13),
#  ('necessari', 13),
#  ('bother', 13),
#  ('stori', 13),
#  ('equip', 13),
#  ('lcd', 13),
#  ('awkward', 13),
#  ('answer', 13),
#  ('togeth', 13),
#  ('solv', 13),
#  ('ten', 13),
#  ('hesit', 13),
#  ('bunch', 13),
#  ('flat', 13),
#  ('link', 13),
#  ('meet', 13),
#  ('challeng', 13),
#  ('fall', 13),
#  ('video', 13),
#  ('explain', 13),
#  ('slowli', 13),
#  ('glitch', 13),
#  ('subscrib', 13),
#  ('invest', 13),
#  ('typic', 13),
#  ('shame', 13),
#  ('clearli', 13),
#  ('difficulti', 13),
#  ('suit', 13),
#  ('cut', 13),
#  ('smooth', 13),
#  ('determin', 13),
#  ('guid', 13),
#  ('began', 13),
#  ('son', 13),
#  ('gotten', 13),
#  ('memori', 13),
#  ('activ', 13),
#  ('handi', 12),
#  ('edit', 12),
#  ('lexmark', 12),
#  ('colleg', 12),
#  ('age', 12),
#  ('flash', 12),
#  ('unus', 12),
#  ('drink', 12),
#  ('poorli', 12),
#  ('dollar', 12),
#  ('drawer', 12),
#  ('form', 12),
#  ('cant', 12),
#  ('lemon', 12),
#  ('individu', 12),
#  ('sens', 12),
#  ('clunki', 12),
#  ('moment', 12),
#  ('shop', 12),
#  ('tricki', 12),
#  ('join', 12),
#  ('smear', 12),
#  ('weight', 12),
#  ('christma', 12),
#  ('everyday', 12),
#  ('earlier', 12),
#  ('buck', 12),
#  ('darn', 12),
#  ('monitor', 12),
#  ('sync', 12),
#  ('unpack', 12),
#  ('arm', 12),
#  ('eat', 12),
#  ('glass', 12),
#  ('tax', 12),
#  ('capac', 12),
#  ('icon', 12),
#  ('beat', 11),
#  ('serv', 11),
#  ('snap', 11),
#  ('disabl', 11),
#  ('bewar', 11),
#  ('build', 11),
#  ('luckili', 11),
#  ('loos', 11),
#  ('protect', 11),
#  ('gray', 11),
#  ('hardwar', 11),
#  ('watch', 11),
#  ('felt', 11),
#  ('stock', 11),
#  ('wow', 11),
#  ('hardwir', 11),
#  ('patient', 11),
#  ('wall', 11),
#  ('fee', 11),
#  ('tend', 11),
#  ('heavi', 11),
#  ...]

# %%
freq1.plot(30)

# %% [markdown]
# ## 2.Lancaster Stemmer

# %%
#Steps are the same with the Porter Stemmer
lancaster = nltk.LancasterStemmer()
stem2 = [lancaster.stem(w) for w in words]
#stem2 = [w for w in stem2]
freq2 = FreqDist(stem2)
sorted_freq2 = sorted(freq2.items(),key = lambda k: k[1], reverse = True)
sorted_freq2
# Out:
# [('print', 7337),
#  ('us', 1590),
#  ('ink', 1331),
#  ('work', 1297),
#  ('easy', 936),
#  ('pap', 918),
#  ('set', 907),
#  ('hp', 885),
#  ('on', 866),
#  ('gre', 833),
#  ('scan', 724),
#  ('canon', 723),
#  ('get', 721),
#  ('good', 702),
#  ('qual', 691),
#  ('tim', 671),
#  ('cartridg', 619),
#  ('lik', 610),
#  ('would', 596),
#  ('connect', 544),
#  ('ev', 536),
#  ('nee', 516),
#  ('photo', 465),
#  ('pag', 450),
#  ('wireless', 436),
#  ('buy', 435),
#  ('wel', 384),
#  ('lov', 379),
#  ('pric', 376),
#  ('replac', 372),
#  ('instal', 356),
#  ('comput', 355),
#  ('tray', 348),
#  ('col', 347),
#  ('problem', 346),
#  ('also', 345),
#  ('real', 338),
#  ('produc', 332),
#  ('setup', 326),
#  ('new', 313),
#  ('cop', 303),
#  ('issu', 302),
#  ('old', 301),
#  ('far', 300),
#  ('fin', 299),
#  ('back', 298),
#  ('look', 296),
#  ('hom', 296),
#  ('wif', 294),
#  ('support', 293),
#  ('phon', 293),
#  ('mak', 291),
#  ('want', 287),
#  ('year', 283),
#  ('thing', 283),
#  ('docu', 279),
#  ('could', 278),
#  ('purchas', 276),
#  ('much', 264),
#  ('bought', 256),
#  ('fast', 256),
#  ('try', 253),
#  ('nic', 252),
#  ('first', 248),
#  ('jam', 243),
#  ('tak', 241),
#  ('last', 236),
#  ('off', 234),
#  ('review', 230),
#  ('long', 227),
#  ('stil', 225),
#  ('got', 224),
#  ('seem', 223),
#  ('littl', 219),
#  ('ap', 218),
#  ('er', 216),
#  ('lot', 215),
#  ('feat', 212),
#  ('com', 211),
#  ('softw', 207),
#  ('recommend', 205),
#  ('day', 204),
#  ('go', 202),
#  ('smal', 202),
#  ('say', 202),
#  ('abl', 201),
#  ('nev', 200),
#  ('month', 200),
#  ('tri', 199),
#  ('black', 195),
#  ('driv', 192),
#  ('return', 192),
#  ('bet', 191),
#  ('screen', 191),
#  ('run', 189),
#  ('turn', 186),
#  ('every', 186),
#  ('op', 184),
#  ('start', 183),
#  ('anoth', 180),
#  ('high', 177),
#  ('network', 172),
#  ('excel', 170),
#  ('happy', 170),
#  ('hour', 169),
#  ('way', 168),
#  ('everyth', 167),
#  ('model', 166),
#  ('quick', 164),
#  ('two', 164),
#  ('fee', 163),
#  ('ca', 162),
#  ('tech', 160),
#  ('amazon', 158),
#  ('machin', 158),
#  ('going', 157),
#  ('giv', 157),
#  ('instruct', 154),
#  ('without', 153),
#  ('man', 152),
#  ('many', 152),
#  ('right', 151),
#  ('find', 150),
#  ('fax', 150),
#  ('job', 149),
#  ('ord', 149),
#  ('sint', 148),
#  ('mess', 146),
#  ('siz', 145),
#  ('box', 145),
#  ('cost', 144),
#  ('slow', 144),
#  ('help', 143),
#  ('someth', 143),
#  ('dev', 142),
#  ('funct', 139),
#  ('perfect', 139),
#  ('opt', 139),
#  ('pretty', 139),
#  ('minut', 137),
#  ('download', 136),
#  ('took', 135),
#  ('think', 135),
#  ('know', 134),
#  ('cal', 134),
#  ('money', 132),
#  ('less', 131),
#  ('cheap', 131),
#  ('sid', 130),
#  ('sur', 128),
#  ('howev', 128),
#  ('cam', 126),
#  ('clear', 126),
#  ('see', 124),
#  ('laptop', 124),
#  ('best', 123),
#  ('keep', 122),
#  ('bit', 122),
#  ('expend', 122),
#  ('yet', 121),
#  ('window', 121),
#  ('pict', 121),
#  ('touch', 119),
#  ('act', 119),
#  ('usb', 119),
#  ('includ', 118),
#  ('hard', 118),
#  ('serv', 117),
#  ('load', 117),
#  ('upd', 116),
#  ('reason', 116),
#  ('simpl', 115),
#  ('expect', 115),
#  ('direct', 114),
#  ('alway', 114),
#  ('mad', 114),
#  ('read', 114),
#  ('send', 110),
#  ('star', 110),
#  ('anyth', 110),
#  ('autom', 109),
#  ('put', 109),
#  ('hold', 108),
#  ('noth', 108),
#  ('disappoint', 108),
#  ('inst', 105),
#  ('though', 105),
#  ('week', 105),
#  ('second', 104),
#  ('stop', 104),
#  ('low', 103),
#  ('sev', 101),
#  ('brand', 99),
#  ('diff', 99),
#  ('own', 98),
#  ('went', 95),
#  ('chang', 95),
#  ('prevy', 95),
#  ('bas', 94),
#  ('plug', 94),
#  ('receiv', 94),
#  ('fig', 94),
#  ('end', 94),
#  ('enough', 93),
#  ('sav', 93),
#  ('design', 92),
#  ('complet', 92),
#  ('mon', 92),
#  ('bad', 92),
#  ('piec', 92),
#  ('ton', 92),
#  ('part', 91),
#  ('im', 90),
#  ('wo', 90),
#  ('epson', 89),
#  ('pow', 89),
#  ('via', 88),
#  ('found', 88),
#  ('ful', 88),
#  ('feel', 88),
#  ('custom', 87),
#  ('hop', 87),
#  ('quit', 87),
#  ('big', 86),
#  ('test', 86),
#  ('let', 86),
#  ('decid', 86),
#  ('avail', 86),
#  ('pleas', 86),
#  ('fix', 85),
#  ('process', 85),
#  ('const', 85),
#  ('tel', 84),
#  ('cabl', 84),
#  ('sheet', 83),
#  ('multipl', 82),
#  ('top', 81),
#  ('frust', 81),
#  ('ship', 80),
#  ('said', 79),
#  ('follow', 79),
#  ('don', 79),
#  ('next', 79),
#  ('onlin', 78),
#  ('wast', 78),
#  ('ad', 78),
#  ('sign', 77),
#  ('spee', 77),
#  ('around', 77),
#  ('iphon', 76),
#  ('plac', 76),
#  ('quiet', 75),
#  ('min', 75),
#  ('difficult', 75),
#  ('pro', 74),
#  ('expery', 73),
#  ('pc', 73),
#  ('sup', 73),
#  ('requir', 72),
#  ('rout', 72),
#  ('unit', 72),
#  ('deal', 72),
#  ('remov', 72),
#  ('lin', 71),
#  ('front', 71),
#  ('cap', 71),
#  ('almost', 71),
#  ('allow', 70),
#  ('not', 70),
#  ('prob', 70),
#  ('pay', 70),
#  ('wish', 70),
#  ('pul', 69),
#  ('officejet', 69),
#  ('busy', 69),
#  ('coupl', 69),
#  ('overal', 69),
#  ('program', 69),
#  ('worst', 69),
#  ('sent', 68),
#  ('sit', 68),
#  ('past', 68),
#  ('pack', 68),
#  ('compact', 68),
#  ('mac', 67),
#  ('may', 67),
#  ('cle', 67),
#  ('panel', 67),
#  ('wor', 66),
#  ('flimsy', 66),
#  ('cod', 66),
#  ('away', 65),
#  ('kept', 65),
#  ('broth', 65),
#  ('amaz', 64),
#  ('wait', 64),
#  ('button', 64),
#  ('sometim', 64),
#  ('whit', 64),
#  ('fair', 63),
#  ('already', 63),
#  ('fact', 63),
#  ('larg', 63),
#  ('brok', 63),
#  ('fit', 62),
#  ('lat', 62),
#  ('show', 62),
#  ('inkjet', 62),
#  ('troubl', 62),
#  ('card', 62),
#  ('cannon', 62),
#  ('point', 61),
#  ('eith', 61),
#  ('ask', 61),
#  ('check', 60),
#  ('spent', 60),
#  ('stay', 60),
#  ('typ', 60),
#  ('guess', 59),
#  ('numb', 59),
#  ('plan', 59),
#  ('ok', 59),
#  ('definit', 58),
#  ('goe', 58),
#  ('half', 58),
#  ('correct', 58),
#  ('gen', 58),
#  ('hap', 57),
#  ('person', 57),
#  ('list', 57),
#  ('item', 57),
#  ('comp', 57),
#  ('refil', 57),
#  ('las', 57),
#  ('email', 56),
#  ('spac', 56),
#  ('thought', 56),
#  ('fre', 56),
#  ('singl', 56),
#  ('head', 56),
#  ('mov', 56),
#  ('mayb', 56),
#  ('mod', 56),
#  ('absolv', 55),
#  ('beauty', 55),
#  ('bluetoo', 55),
#  ('annoy', 55),
#  ('tot', 55),
#  ('although', 55),
#  ('clos', 55),
#  ('gav', 55),
#  ('websit', 54),
#  ('hook', 54),
#  ('sery', 53),
#  ('etc', 53),
#  ('pixm', 53),
#  ('dec', 53),
#  ('provid', 53),
#  ('extrem', 53),
#  ('resolv', 53),
#  ('awesom', 53),
#  ('tank', 53),
#  ('light', 52),
#  ('friend', 52),
#  ('per', 52),
#  ('text', 52),
#  ('peopl', 51),
#  ('rely', 51),
#  ('fail', 51),
#  ('three', 51),
#  ('plast', 51),
#  ('room', 51),
#  ('useless', 51),
#  ('ar', 51),
#  ('spec', 50),
#  ('align', 50),
#  ('instead', 50),
#  ('step', 50),
#  ('exact', 50),
#  ('rat', 49),
#  ('smart', 49),
#  ('prop', 49),
#  ('internet', 49),
#  ('perform', 49),
#  ('junk', 49),
#  ('duplex', 49),
#  ('output', 49),
#  ('system', 49),
#  ('rear', 49),
#  ('exceiv', 48),
#  ('origin', 48),
#  ('els', 48),
#  ('ipad', 48),
#  ('must', 48),
#  ('least', 48),
#  ('rel', 48),
#  ('stor', 47),
#  ('init', 47),
#  ('loc', 47),
#  ('describ', 47),
#  ('vert', 47),
#  ('desk', 47),
#  ('control', 46),
#  ('mat', 46),
#  ('stat', 46),
#  ('told', 46),
#  ('poor', 46),
#  ('ago', 45),
#  ('main', 45),
#  ('cd', 45),
#  ('oft', 45),
#  ('lif', 44),
#  ('upgrad', 44),
#  ('fil', 44),
#  ('bottom', 44),
#  ('tablet', 44),
#  ('touchscreen', 44),
#  ('kind', 44),
#  ('troubleshoot', 44),
#  ('select', 44),
#  ('cur', 44),
#  ('display', 44),
#  ('thank', 43),
#  ('complaint', 43),
#  ('unless', 43),
#  ('suppos', 43),
#  ('mean', 43),
#  ('might', 43),
#  ('rath', 43),
#  ('sel', 43),
#  ('research', 42),
#  ('car', 42),
#  ('company', 42),
#  ('regul', 42),
#  ('espec', 42),
#  ('googl', 42),
#  ('plain', 42),
#  ('result', 42),
#  ('doubl', 42),
#  ('label', 42),
#  ('reinstal', 42),
#  ('respond', 42),
#  ('mobl', 41),
#  ('continu', 41),
#  ('pain', 41),
#  ('miss', 41),
#  ('jet', 41),
#  ('impress', 41),
#  ('valu', 41),
#  ('wir', 41),
#  ('drop', 40),
#  ('hous', 40),
#  ('gon', 40),
#  ('consid', 40),
#  ('tru', 40),
#  ('addit', 39),
#  ('oth', 39),
#  ('x', 39),
#  ('advert', 39),
#  ('reg', 39),
#  ('recogn', 38),
#  ('level', 38),
#  ('contact', 38),
#  ('limit', 38),
#  ('adjust', 38),
#  ('appl', 38),
#  ('understand', 38),
#  ('shut', 38),
#  ('appear', 38),
#  ('spend', 38),
#  ('cord', 38),
#  ('garb', 38),
#  ('warranty', 38),
#  ('disc', 38),
#  ('today', 37),
#  ('desktop', 37),
#  ('warn', 37),
#  ('access', 37),
#  ('hat', 37),
#  ('within', 37),
#  ('wrong', 37),
#  ('surpr', 37),
#  ('near', 36),
#  ('terr', 36),
#  ('plu', 36),
#  ('form', 36),
#  ('non', 36),
#  ('aw', 36),
#  ('wond', 36),
#  ('ready', 36),
#  ('subscrib', 36),
#  ('inform', 35),
#  ('extr', 35),
#  ('died', 35),
#  ('default', 35),
#  ('paid', 35),
#  ('del', 35),
#  ('norm', 35),
#  ('break', 35),
#  ('restart', 35),
#  ('horr', 35),
#  ('eas', 35),
#  ('despit', 34),
#  ('ethernet', 34),
#  ('photograph', 34),
#  ('cas', 34),
#  ('anyon', 34),
#  ('whol', 34),
#  ('standard', 34),
#  ('visit', 34),
#  ('report', 33),
#  ('cours', 33),
#  ('simply', 33),
#  ('insert', 33),
#  ('ye', 33),
#  ('acceiv', 33),
#  ('search', 32),
#  ('due', 32),
#  ('breez', 32),
#  ('conveny', 32),
#  ('frequ', 32),
#  ('otherw', 32),
#  ('six', 32),
#  ('cloud', 32),
#  ('anywh', 31),
#  ('school', 31),
#  ('w', 31),
#  ('comply', 31),
#  ('suggest', 31),
#  ('stuff', 31),
#  ('push', 31),
#  ('satisfy', 31),
#  ('cho', 31),
#  ('forev', 31),
#  ('airprint', 31),
#  ('someon', 30),
#  ('crisp', 30),
#  ('hit', 30),
#  ('click', 30),
#  ('footprint', 30),
#  ('cov', 30),
#  ('occas', 30),
#  ('compat', 30),
#  ('soon', 30),
#  ('apply', 30),
#  ('unplug', 30),
#  ('writ', 30),
#  ('poss', 30),
#  ('menu', 30),
#  ('talk', 29),
#  ('techn', 29),
#  ('reset', 29),
#  ('caus', 29),
#  ('solv', 29),
#  ('lit', 29),
#  ('interfac', 29),
#  ('neg', 29),
#  ('blu', 29),
#  ('success', 29),
#  ('confus', 29),
#  ('bar', 29),
#  ('leav', 28),
#  ('third', 28),
#  ('rec', 28),
#  ('thu', 28),
#  ('profess', 28),
#  ('pop', 28),
#  ('afford', 28),
#  ('crap', 28),
#  ('nam', 28),
#  ('stuck', 28),
#  ('auto', 28),
#  ('fantast', 28),
#  ('wak', 28),
#  ('extend', 28),
#  ('offlin', 28),
#  ('charg', 28),
#  ('short', 27),
#  ('ide', 27),
#  ('account', 27),
#  ('suck', 27),
#  ('liv', 27),
#  ('hug', 27),
#  ('b', 27),
#  ('stick', 27),
#  ('hand', 27),
#  ('party', 27),
#  ('attempt', 27),
#  ('attach', 27),
#  ('sleep', 27),
#  ('amount', 27),
#  ('consum', 27),
#  ('famy', 26),
#  ('pref', 26),
#  ('glad', 26),
#  ('play', 26),
#  ('ind', 26),
#  ('switch', 26),
#  ('purpos', 25),
#  ('rang', 25),
#  ('pick', 25),
#  ('maj', 25),
#  ('import', 25),
#  ('volum', 25),
#  ('forc', 25),
#  ('chos', 25),
#  ('twic', 25),
#  ('supply', 25),
#  ('saw', 25),
#  ('zero', 25),
#  ('period', 25),
#  ('posit', 25),
#  ('firmw', 25),
#  ('immedy', 24),
#  ('un', 24),
#  ('disconnect', 24),
#  ('vary', 24),
#  ('onto', 24),
#  ('built', 24),
#  ('manufact', 24),
#  ('envelop', 24),
#  ('pdf', 24),
#  ('world', 24),
#  ('xl', 24),
#  ('market', 24),
#  ('lack', 24),
#  ('ment', 24),
#  ('med', 24),
#  ('password', 23),
#  ('mom', 23),
#  ('ear', 23),
#  ('sep', 23),
#  ('okay', 23),
#  ('anyway', 23),
#  ('ridic', 23),
#  ('solid', 23),
#  ('left', 23),
#  ('efficy', 23),
#  ('cel', 23),
#  ('speak', 23),
#  ('smartphon', 22),
#  ('remot', 22),
#  ('app', 22),
#  ('ran', 22),
#  ('learn', 22),
#  ('port', 22),
#  ('commun', 22),
#  ('enjoy', 22),
#  ('word', 22),
#  ('cre', 22),
#  ('believ', 22),
#  ('catch', 22),
#  ('flawless', 22),
#  ('handl', 22),
#  ('av', 22),
#  ('press', 22),
#  ('quest', 22),
#  ('sal', 22),
#  ('android', 22),
#  ('intuit', 22),
#  ('anym', 21),
#  ('address', 21),
#  ('four', 21),
#  ('minim', 21),
#  ('prompt', 21),
#  ('air', 21),
#  ('chant', 21),
#  ('seen', 21),
#  ('sharp', 21),
#  ('imposs', 21),
#  ('husband', 21),
#  ('technolog', 21),
#  ('most', 21),
#  ('defect', 21),
#  ('detect', 20),
#  ('info', 20),
#  ('mistak', 20),
#  ('outstand', 20),
#  ('honest', 20),
#  ('along', 20),
#  ('kid', 20),
#  ('discov', 20),
#  ('reconnect', 20),
#  ('slid', 20),
#  ('draw', 20),
#  ('improv', 20),
#  ('lan', 20),
#  ('cancel', 20),
#  ('blank', 20),
#  ('dont', 20),
#  ('entir', 20),
#  ('inexpend', 20),
#  ('trash', 20),
#  ('unfortun', 20),
#  ('worry', 20),
#  ('empty', 20),
#  ('dry', 20),
#  ('retract', 20),
#  ('chat', 19),
#  ('macbook', 19),
#  ('pract', 19),
#  ('choos', 19),
#  ('wors', 19),
#  ('luck', 19),
#  ('rep', 19),
#  ('sleek', 19),
#  ('certain', 19),
#  ('fiv', 19),
#  ('dat', 19),
#  ('dai', 19),
#  ('cumbersom', 19),
#  ('config', 19),
#  ('simil', 19),
#  ('slot', 19),
#  ('od', 19),
#  ('concern', 18),
#  ('easiest', 18),
#  ('term', 18),
#  ('project', 18),
#  ('prim', 18),
#  ('refund', 18),
#  ('mark', 18),
#  ('rar', 18),
#  ('delivery', 18),
#  ('crazy', 18),
#  ('mind', 18),
#  ('navig', 18),
#  ('sampl', 18),
#  ('detail', 18),
#  ('sound', 18),
#  ('prep', 18),
#  ('amir', 18),
#  ('stand', 17),
#  ('slight', 17),
#  ('whatev', 17),
#  ('straight', 17),
#  ('bright', 17),
#  ('cheaply', 17),
#  ('across', 17),
#  ('ag', 17),
#  ('begin', 17),
#  ('necess', 17),
#  ('los', 17),
#  ('beyond', 17),
#  ('incred', 17),
#  ('biggest', 17),
#  ('sens', 17),
#  ('tap', 17),
#  ('styl', 17),
#  ('unrely', 17),
#  ('task', 17),
#  ('draft', 17),
#  ('dislik', 17),
#  ('doc', 17),
#  ('rol', 17),
#  ('rememb', 17),
#  ('guid', 17),
#  ('glossy', 17),
#  ('lost', 16),
#  ('sec', 16),
#  ('assum', 16),
#  ('becom', 16),
#  ('assist', 16),
#  ('stud', 16),
#  ('thru', 16),
#  ('noisy', 16),
#  ('os', 16),
#  ('web', 16),
#  ('excess', 16),
#  ('flo', 16),
#  ('excit', 16),
#  ('paty', 16),
#  ('pri', 16),
#  ('delet', 16),
#  ('envy', 16),
#  ('engin', 16),
#  ('charm', 16),
#  ('hassl', 16),
#  ('shoot', 16),
#  ('nightm', 16),
#  ('heavy', 16),
#  ('con', 16),
#  ('carry', 16),
#  ('nois', 16),
#  ('oh', 16),
#  ('fing', 16),
#  ('cool', 15),
#  ('magent', 15),
#  ('spot', 15),
#  ('unus', 15),
#  ('lucky', 15),
#  ('walk', 15),
#  ('opin', 15),
#  ('latest', 15),
#  ('refus', 15),
#  ('lift', 15),
#  ('phys', 15),
#  ('util', 15),
#  ('num', 15),
#  ('door', 15),
#  ('book', 15),
#  ('insid', 15),
#  ('electron', 15),
#  ('chromebook', 15),
#  ('adf', 15),
#  ('fan', 15),
#  ('adv', 15),
#  ('reboot', 15),
#  ('io', 15),
#  ('smooth', 15),
#  ('gift', 15),
#  ('wheth', 15),
#  ('repair', 15),
#  ('stupid', 14),
#  ('awhil', 14),
#  ('ent', 14),
#  ('multifunct', 14),
#  ('somewh', 14),
#  ('doubt', 14),
#  ('virt', 14),
#  ('knew', 14),
#  ('everyon', 14),
#  ('guy', 14),
#  ('awkward', 14),
#  ('alon', 14),
#  ('match', 14),
#  ('flip', 14),
#  ('fut', 14),
#  ('are', 14),
#  ('tiny', 14),
#  ('mech', 14),
#  ('fal', 14),
#  ('dam', 14),
#  ('cyc', 14),
#  ('sham', 14),
#  ('avoid', 14),
#  ('suit', 14),
#  ('cut', 14),
#  ('claim', 14),
#  ('random', 14),
#  ('determin', 14),
#  ('sud', 14),
#  ('depend', 14),
#  ('cart', 14),
#  ('attract', 14),
#  ('headach', 14),
#  ('uninstal', 14),
#  ('beg', 14),
#  ('pic', 14),
#  ('id', 14),
#  ('pair', 14),
#  ('upon', 14),
#  ('inch', 14),
#  ('weird', 13),
#  ('rest', 13),
#  ('pass', 13),
#  ('edit', 13),
#  ('particul', 13),
#  ('cyan', 13),
#  ('worthless', 13),
#  ('middl', 13),
#  ('log', 13),
#  ('consist', 13),
#  ('both', 13),
#  ('story', 13),
#  ('obvy', 13),
#  ('equip', 13),
#  ('lcd', 13),
#  ('answ', 13),
#  ('togeth', 13),
#  ('ten', 13),
#  ('arm', 13),
#  ('hesit', 13),
#  ('protect', 13),
#  ('bunch', 13),
#  ('flat', 13),
#  ('clunky', 13),
#  ('link', 13),
#  ('meet', 13),
#  ('challeng', 13),
#  ('video', 13),
#  ('explain', 13),
#  ('glitch', 13),
#  ('invest', 13),
#  ('difficul', 13),
#  ('smoo', 13),
#  ('unpack', 13),
#  ('tend', 13),
#  ('throw', 13),
#  ('son', 13),
#  ('mem', 13),
#  ('camera', 13),
#  ('handy', 12),
#  ('lexmark', 12),
#  ('colleg', 12),
#  ('art', 12),
#  ('flash', 12),
#  ('agr', 12),
#  ('par', 12),
#  ('drink', 12),
#  ('doll', 12),
#  ('cant', 12),
#  ('loos', 12),
#  ('lemon', 12),
#  ('individ', 12),
#  ('shop', 12),
#  ('tricky', 12),
#  ('join', 12),
#  ('smear', 12),
#  ('weight', 12),
#  ('christmas', 12),
#  ('everyday', 12),
#  ('buck', 12),
#  ('wal', 12),
#  ('darn', 12),
#  ('monit', 12),
#  ('synt', 12),
#  ('eat', 12),
#  ('refurb', 12),
#  ('glass', 12),
#  ('tax', 12),
#  ('capac', 12),
#  ('icon', 12),
#  ('spok', 11),
#  ('beat', 11),
#  ('spit', 11),
#  ('rid', 11),
#  ('snap', 11),
#  ('dis', 11),
#  ('bew', 11),
#  ('build', 11),
#  ('post', 11),
#  ('seamless', 11),
#  ('reduc', 11),
#  ('graph', 11),
#  ('gray', 11),
#  ('hardw', 11),
#  ('watch', 11),
#  ('felt', 11),
#  ('stock', 11),
#  ('wow', 11),
#  ('hps', 11),
#  ('hardwir', 11),
#  ('tedy', 11),
#  ('complain', 11),
#  ('bil', 11),
#  ('wont', 11),
#  ('red', 11),
#  ('cent', 11),
#  ('flap', 11),
#  ('apprecy', 11),
#  ('doz', 11),
#  ('standby', 11),
#  ('sd', 11),
#  ('xxl', 11),
#  ('digit', 10),
#  ('unlik', 10),
#  ('in', 10),
#  ('workhors', 10),
#  ('yellow', 10),
#  ('en', 10),
#  ('fir', 10),
#  ('teach', 10),
#  ('night', 10),
#  ('lightweight', 10),
#  ('expir', 10),
#  ('construct', 10),
#  ('inconveny', 10),
#  ('effort', 10),
#  ('contain', 10),
#  ('dust', 10),
#  ('repl', 10),
#  ('recyc', 10),
#  ('yesterday', 10),
#  ('lock', 10),
#  ('reach', 10),
#  ('yr', 10),
#  ('plat', 10),
#  ('vibr', 10),
#  ('malfunct', 10),
#  ('shelf', 10),
#  ('apart', 10),
#  ('forget', 10),
#  ('pos', 10),
#  ('ser', 10),
#  ('scam', 10),
#  ('jok', 10),
#  ('printout', 10),
#  ('competit', 10),
#  ('endless', 10),
#  ('interest', 10),
#  ('unbox', 10),
#  ('prev', 10),
#  ('homework', 10),
#  ('adequ', 10),
#  ('request', 10),
#  ('surfac', 10),
#  ('irrit', 10),
#  ('at', 10),
#  ('econom', 10),
#  ...]

# %%
freq2.plot(30)

# %% [markdown]
# ### 3.WordNet Lemmatizer

# %%
nltk.download('wordnet')
#Steps are the same with the previous two stemmers 
wnl = nltk.WordNetLemmatizer()
stem3 = [wnl.lemmatize(w) for w in words]
freq3 = FreqDist(stem3)
sorted_freq3 = sorted(freq3.items(),key = lambda k: k[1], reverse = True)
sorted_freq3
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/isabelleliu/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [('printer', 4248),
#  ('print', 2008),
#  ('ink', 1330),
#  ('work', 949),
#  ('paper', 917),
#  ('hp', 896),
#  ('one', 865),
#  ('printing', 846),
#  ('use', 836),
#  ('great', 827),
#  ('easy', 812),
#  ('set', 742),
#  ('canon', 723),
#  ('good', 697),
#  ('quality', 689),
#  ('time', 666),
#  ('cartridge', 619),
#  ('would', 595),
#  ('get', 577),
#  ('like', 562),
#  ('photo', 465),
#  ('page', 449),
#  ('wireless', 389),
#  ('well', 384),
#  ('need', 376),
#  ('even', 361),
#  ('price', 354),
#  ('computer', 353),
#  ('scan', 351),
#  ('buy', 351),
#  ('tray', 348),
#  ('also', 345),
#  ('problem', 344),
#  ('love', 336),
#  ('color', 326),
#  ('setup', 325),
#  ('product', 302),
#  ('far', 299),
#  ('issue', 298),
#  ('home', 296),
#  ('phone', 293),
#  ('back', 292),
#  ('new', 289),
#  ('year', 283),
#  ('thing', 283),
#  ('support', 279),
#  ('could', 278),
#  ('month', 277),
#  ('really', 275),
#  ('much', 264),
#  ('document', 264),
#  ('used', 264),
#  ('wifi', 263),
#  ('go', 260),
#  ('bought', 256),
#  ('first', 248),
#  ('old', 237),
#  ('make', 237),
#  ('printed', 229),
#  ('nice', 227),
#  ('still', 225),
#  ('using', 221),
#  ('little', 219),
#  ('lot', 215),
#  ('error', 215),
#  ('got', 211),
#  ('feature', 210),
#  ('fast', 210),
#  ('want', 208),
#  ('software', 207),
#  ('review', 206),
#  ('day', 204),
#  ('app', 202),
#  ('take', 200),
#  ('never', 200),
#  ('screen', 198),
#  ('last', 196),
#  ('black', 195),
#  ('copy', 188),
#  ('better', 187),
#  ('every', 186),
#  ('office', 182),
#  ('another', 180),
#  ('worked', 179),
#  ('connection', 177),
#  ('jam', 173),
#  ('tried', 171),
#  ('come', 170),
#  ('hour', 169),
#  ('working', 169),
#  ('way', 168),
#  ('scanning', 168),
#  ('look', 167),
#  ('everything', 167),
#  ('model', 166),
#  ('network', 166),
#  ('recommend', 166),
#  ('scanner', 165),
#  ('say', 165),
#  ('setting', 165),
#  ('install', 164),
#  ('two', 164),
#  ('small', 162),
#  ('ca', 162),
#  ('able', 161),
#  ('excellent', 161),
#  ('connect', 161),
#  ('happy', 161),
#  ('driver', 160),
#  ('tech', 160),
#  ('amazon', 158),
#  ('machine', 158),
#  ('going', 157),
#  ('long', 154),
#  ('without', 153),
#  ('instruction', 152),
#  ('many', 152),
#  ('fine', 151),
#  ('right', 151),
#  ('job', 149),
#  ('since', 147),
#  ('ever', 147),
#  ('getting', 144),
#  ('something', 143),
#  ('device', 142),
#  ('try', 141),
#  ('purchase', 141),
#  ('size', 139),
#  ('box', 139),
#  ('cost', 138),
#  ('pretty', 138),
#  ('find', 137),
#  ('minute', 137),
#  ('replacement', 137),
#  ('needed', 137),
#  ('took', 135),
#  ('seems', 135),
#  ('turn', 133),
#  ('le', 132),
#  ('money', 132),
#  ('know', 130),
#  ('fax', 128),
#  ('however', 128),
#  ('sure', 125),
#  ('trying', 125),
#  ('laptop', 124),
#  ('message', 124),
#  ('came', 123),
#  ('best', 123),
#  ('return', 123),
#  ('replace', 123),
#  ('yet', 121),
#  ('window', 121),
#  ('connected', 121),
#  ('expensive', 121),
#  ('bit', 120),
#  ('option', 119),
#  ('see', 119),
#  ('run', 119),
#  ('usb', 119),
#  ('picture', 119),
#  ('touch', 117),
#  ('purchased', 115),
#  ('always', 114),
#  ('help', 111),
#  ('star', 110),
#  ('anything', 110),
#  ('slow', 110),
#  ('keep', 108),
#  ('nothing', 108),
#  ('made', 107),
#  ('finally', 105),
#  ('though', 105),
#  ('service', 104),
#  ('simple', 104),
#  ('think', 102),
#  ('week', 102),
#  ('hard', 102),
#  ('give', 99),
#  ('several', 98),
#  ('update', 97),
#  ('second', 96),
#  ('brand', 96),
#  ('function', 96),
#  ('went', 95),
#  ('put', 95),
#  ('clear', 95),
#  ('enough', 93),
#  ('cheap', 92),
#  ('piece', 92),
#  ('looking', 91),
#  ('user', 91),
#  ('instant', 90),
#  ('hold', 90),
#  ('perfect', 90),
#  ('wo', 90),
#  ('quickly', 90),
#  ('bad', 89),
#  ('low', 89),
#  ('high', 88),
#  ('via', 88),
#  ('found', 88),
#  ('owned', 87),
#  ('epson', 85),
#  ('cable', 84),
#  ('sheet', 83),
#  ('easily', 83),
#  ('part', 83),
#  ('multiple', 82),
#  ('send', 81),
#  ('top', 80),
#  ('customer', 80),
#  ('image', 80),
#  ('different', 80),
#  ('reason', 80),
#  ('feel', 80),
#  ('said', 79),
#  ('installed', 79),
#  ('actually', 79),
#  ('start', 79),
#  ('read', 79),
#  ('next', 79),
#  ('online', 78),
#  ('done', 78),
#  ('started', 77),
#  ('speed', 77),
#  ('around', 77),
#  ('previous', 77),
#  ('pc', 77),
#  ('order', 76),
#  ('buying', 75),
#  ('difficult', 75),
#  ('pro', 74),
#  ('replaced', 74),
#  ('disappointed', 74),
#  ('manual', 74),
#  ('feeder', 73),
#  ('feed', 73),
#  ('side', 73),
#  ('longer', 73),
#  ('super', 73),
#  ('full', 73),
#  ('automatically', 72),
#  ('process', 72),
#  ('front', 71),
#  ('almost', 71),
#  ('line', 70),
#  ('router', 70),
#  ('big', 70),
#  ('download', 70),
#  ('running', 70),
#  ('unit', 70),
#  ('officejet', 69),
#  ('wanted', 69),
#  ('couple', 69),
#  ('overall', 69),
#  ('worst', 69),
#  ('wish', 69),
#  ('open', 69),
#  ('iphone', 68),
#  ('sent', 68),
#  ('program', 68),
#  ('deal', 68),
#  ('quite', 68),
#  ('toner', 68),
#  ('mac', 67),
#  ('tell', 67),
#  ('may', 67),
#  ('quick', 67),
#  ('highly', 67),
#  ('installation', 67),
#  ('fix', 67),
#  ('compact', 67),
#  ('power', 67),
#  ('panel', 67),
#  ('quiet', 66),
#  ('probably', 66),
#  ('available', 66),
#  ('away', 65),
#  ('change', 65),
#  ('worth', 65),
#  ('flimsy', 65),
#  ('business', 65),
#  ('kept', 65),
#  ('call', 65),
#  ('code', 65),
#  ('received', 65),
#  ('past', 65),
#  ('brother', 65),
#  ('constantly', 65),
#  ('called', 64),
#  ('save', 64),
#  ('older', 64),
#  ('button', 64),
#  ('white', 64),
#  ('already', 63),
#  ('let', 63),
#  ('sometimes', 63),
#  ('expected', 63),
#  ('trouble', 62),
#  ('card', 62),
#  ('cannon', 62),
#  ('either', 61),
#  ('fit', 60),
#  ('half', 60),
#  ('spent', 60),
#  ('pleased', 60),
#  ('test', 60),
#  ('decided', 59),
#  ('ordered', 59),
#  ('included', 59),
#  ('ok', 59),
#  ('point', 58),
#  ('number', 58),
#  ('inkjet', 58),
#  ('end', 58),
#  ('pay', 58),
#  ('stopped', 57),
#  ('item', 57),
#  ('experience', 57),
#  ('sided', 57),
#  ('laser', 57),
#  ('single', 56),
#  ('amazing', 56),
#  ('maybe', 56),
#  ('figure', 56),
#  ('space', 55),
#  ('thought', 55),
#  ('free', 55),
#  ('bluetooth', 55),
#  ('waste', 55),
#  ('although', 55),
#  ('add', 55),
#  ('gave', 55),
#  ('guess', 54),
#  ('plug', 54),
#  ('definitely', 54),
#  ('website', 54),
#  ('copier', 54),
#  ('fact', 53),
#  ('place', 53),
#  ('etc', 53),
#  ('pixma', 53),
#  ('awesome', 53),
#  ('tank', 53),
#  ('email', 52),
#  ('load', 52),
#  ('head', 52),
#  ('per', 52),
#  ('people', 51),
#  ('three', 51),
#  ('plastic', 51),
#  ('room', 51),
#  ('cd', 51),
#  ('useless', 51),
#  ('extremely', 51),
#  ('text', 51),
#  ('instead', 50),
#  ('step', 50),
#  ('fairly', 49),
#  ('light', 49),
#  ('internet', 49),
#  ('capability', 49),
#  ('plan', 49),
#  ('making', 49),
#  ('output', 49),
#  ('system', 49),
#  ('refill', 49),
#  ('rear', 49),
#  ('perfectly', 48),
#  ('else', 48),
#  ('pull', 48),
#  ('smart', 48),
#  ('must', 48),
#  ('hope', 48),
#  ('least', 48),
#  ('junk', 48),
#  ('stay', 48),
#  ('design', 48),
#  ('manually', 47),
#  ('life', 47),
#  ('u', 47),
#  ('mode', 47),
#  ('desk', 47),
#  ('directly', 46),
#  ('told', 46),
#  ('large', 46),
#  ('type', 46),
#  ('us', 46),
#  ('wirelessly', 46),
#  ('copying', 45),
#  ('ago', 45),
#  ('frustrating', 45),
#  ('often', 45),
#  ('faster', 45),
#  ('duplex', 45),
#  ('completely', 45),
#  ('original', 44),
#  ('control', 44),
#  ('later', 44),
#  ('turned', 44),
#  ('bottom', 44),
#  ('tablet', 44),
#  ('touchscreen', 44),
#  ('decent', 44),
#  ('remove', 44),
#  ('shipping', 44),
#  ('seem', 43),
#  ('complaint', 43),
#  ('unless', 43),
#  ('properly', 43),
#  ('might', 43),
#  ('stop', 43),
#  ('rather', 43),
#  ('exactly', 43),
#  ('version', 43),
#  ('seemed', 42),
#  ('ipad', 42),
#  ('company', 42),
#  ('especially', 42),
#  ('double', 42),
#  ('downloaded', 41),
#  ('check', 41),
#  ('google', 41),
#  ('jet', 41),
#  ('returned', 41),
#  ('plain', 41),
#  ('value', 41),
#  ('label', 41),
#  ('scanned', 40),
#  ('mobile', 40),
#  ('annoying', 40),
#  ('ability', 40),
#  ('smaller', 40),
#  ('easier', 40),
#  ('house', 39),
#  ('absolutely', 39),
#  ('others', 39),
#  ('compared', 39),
#  ('x', 39),
#  ('relatively', 39),
#  ('kind', 39),
#  ('basic', 38),
#  ('reliable', 38),
#  ('regular', 38),
#  ('mean', 38),
#  ('show', 38),
#  ('level', 38),
#  ('apple', 38),
#  ('follow', 38),
#  ('cord', 38),
#  ('installing', 38),
#  ('looked', 38),
#  ('garbage', 38),
#  ('arrived', 38),
#  ('disc', 38),
#  ('today', 37),
#  ('desktop', 37),
#  ('cheaper', 37),
#  ('liked', 37),
#  ('within', 37),
#  ('jammed', 37),
#  ('wait', 37),
#  ('warranty', 37),
#  ('direct', 36),
#  ('giving', 36),
#  ('plus', 36),
#  ('pain', 36),
#  ('complete', 36),
#  ('saying', 36),
#  ('allows', 36),
#  ('wrong', 36),
#  ('designed', 35),
#  ('connecting', 35),
#  ('extra', 35),
#  ('died', 35),
#  ('paid', 35),
#  ('result', 35),
#  ('close', 35),
#  ('horrible', 35),
#  ('display', 35),
#  ('clean', 34),
#  ('real', 34),
#  ('despite', 34),
#  ('offer', 34),
#  ('ethernet', 34),
#  ('anyone', 34),
#  ('whole', 34),
#  ('standard', 34),
#  ('poor', 34),
#  ('troubleshooting', 34),
#  ('yes', 34),
#  ('ease', 34),
#  ('thinking', 33),
#  ('course', 33),
#  ('simply', 33),
#  ('file', 33),
#  ('understand', 33),
#  ('menu', 33),
#  ('terrible', 32),
#  ('due', 32),
#  ('initial', 32),
#  ('breeze', 32),
#  ('replacing', 32),
#  ('connectivity', 32),
#  ('otherwise', 32),
#  ('loaded', 32),
#  ('cloud', 32),
#  ('broken', 32),
#  ('plugged', 31),
#  ('person', 31),
#  ('anywhere', 31),
#  ('gone', 31),
#  ('series', 31),
#  ('alignment', 31),
#  ('beautiful', 31),
#  ('default', 31),
#  ('wife', 31),
#  ('school', 31),
#  ('w', 31),
#  ('figured', 31),
#  ('site', 31),
#  ('direction', 31),
#  ('ready', 31),
#  ('choice', 31),
#  ('jamming', 31),
#  ('broke', 31),
#  ('forever', 31),
#  ('including', 31),
#  ('airprint', 31),
#  ('someone', 30),
#  ('required', 30),
#  ('research', 30),
#  ('supposed', 30),
#  ('crisp', 30),
#  ('loved', 30),
#  ('main', 30),
#  ('b', 30),
#  ('stuff', 30),
#  ('footprint', 30),
#  ('move', 30),
#  ('operate', 30),
#  ('drive', 30),
#  ('friendly', 30),
#  ('advertised', 30),
#  ('six', 30),
#  ('normal', 30),
#  ('visitor', 30),
#  ('except', 29),
#  ('hit', 29),
#  ('limited', 29),
#  ('based', 29),
#  ('frequently', 29),
#  ('hate', 29),
#  ('interface', 29),
#  ('totally', 29),
#  ('lasted', 29),
#  ('negative', 29),
#  ('upgrade', 29),
#  ('automatic', 29),
#  ('ended', 29),
#  ('wired', 29),
#  ('list', 29),
#  ('information', 28),
#  ('store', 28),
#  ('third', 28),
#  ('thus', 28),
#  ('access', 28),
#  ('reading', 28),
#  ('complicated', 28),
#  ('crap', 28),
#  ('name', 28),
#  ('stuck', 28),
#  ('auto', 28),
#  ('noticed', 28),
#  ('soon', 28),
#  ('fantastic', 28),
#  ('satisfied', 28),
#  ('correctly', 28),
#  ('offline', 28),
#  ('register', 28),
#  ('idea', 27),
#  ('matter', 27),
#  ('returning', 27),
#  ('huge', 27),
#  ('taking', 27),
#  ('none', 27),
#  ('mine', 27),
#  ('cover', 27),
#  ('party', 27),
#  ('warning', 27),
#  ('amount', 27),
#  ('correct', 26),
#  ('true', 26),
#  ('case', 26),
#  ('family', 26),
#  ('usually', 26),
#  ('expect', 26),
#  ('hand', 26),
#  ('loading', 26),
#  ('compatible', 26),
#  ('sign', 26),
#  ('blue', 26),
#  ('spend', 26),
#  ('recommended', 26),
#  ('sleep', 26),
#  ('usage', 26),
#  ('purpose', 25),
#  ('professional', 25),
#  ('convenient', 25),
#  ('literally', 25),
#  ('volume', 25),
#  ('ask', 25),
#  ('glad', 25),
#  ('wake', 25),
#  ('impressed', 25),
#  ('chose', 25),
#  ('twice', 25),
#  ('awful', 25),
#  ('saw', 25),
#  ('xl', 25),
#  ('provided', 25),
#  ('zero', 25),
#  ('firmware', 25),
#  ('account', 24),
#  ('followed', 24),
#  ('major', 24),
#  ('onto', 24),
#  ('built', 24),
#  ('finish', 24),
#  ('break', 24),
#  ('hook', 24),
#  ('pdf', 24),
#  ('world', 24),
#  ('confusing', 24),
#  ('reset', 24),
#  ('password', 23),
#  ('happened', 23),
#  ('immediately', 23),
#  ('total', 23),
#  ('okay', 23),
#  ('range', 23),
#  ('opened', 23),
#  ('important', 23),
#  ('description', 23),
#  ('left', 23),
#  ('sending', 23),
#  ('click', 23),
#  ('subscription', 23),
#  ('cell', 23),
#  ('operation', 23),
#  ('pack', 23),
#  ('hooked', 23),
#  ('rating', 22),
#  ('failed', 22),
#  ('nearly', 22),
#  ('ran', 22),
#  ('word', 22),
#  ('given', 22),
#  ('frustration', 22),
#  ('short', 22),
#  ('adjust', 22),
#  ('allow', 22),
#  ('envelope', 22),
#  ('restart', 22),
#  ('personal', 22),
#  ('possible', 22),
#  ('resolve', 22),
#  ('currently', 22),
#  ('reasonable', 22),
#  ('min', 22),
#  ('sale', 22),
#  ('sell', 22),
#  ('higher', 22),
#  ('android', 22),
#  ('local', 22),
#  ('surprised', 22),
#  ('intuitive', 22),
#  ('medium', 22),
#  ('functionality', 21),
#  ('anymore', 21),
#  ('addition', 21),
#  ('suck', 21),
#  ('air', 21),
#  ('performance', 21),
#  ('solid', 21),
#  ('chance', 21),
#  ('seen', 21),
#  ('coming', 21),
#  ('cleaning', 21),
#  ('impossible', 21),
#  ('described', 21),
#  ('shut', 21),
#  ('husband', 21),
#  ('average', 21),
#  ('area', 21),
#  ('receive', 21),
#  ('barely', 21),
#  ('current', 21),
#  ('mostly', 21),
#  ('info', 20),
#  ('care', 20),
#  ('nicely', 20),
#  ('faxing', 20),
#  ('recognize', 20),
#  ('purchasing', 20),
#  ('outstanding', 20),
#  ('recently', 20),
#  ('report', 20),
#  ('along', 20),
#  ('minor', 20),
#  ('unable', 20),
#  ('contact', 20),
#  ('thanks', 20),
#  ('friend', 20),
#  ('priced', 20),
#  ('thank', 20),
#  ('drop', 20),
#  ('occasional', 20),
#  ('prefer', 20),
#  ('lan', 20),
#  ('blank', 20),
#  ('dont', 20),
#  ('push', 20),
#  ('letter', 20),
#  ('inexpensive', 20),
#  ('removed', 20),
#  ('requires', 20),
#  ('charge', 20),
#  ('question', 20),
#  ('slower', 20),
#  ('shipped', 20),
#  ('beautifully', 20),
#  ('play', 20),
#  ('period', 20),
#  ('constant', 20),
#  ('empty', 20),
#  ('tested', 19),
#  ('worse', 19),
#  ('luck', 19),
#  ('anyway', 19),
#  ('downloading', 19),
#  ('capable', 19),
#  ('sleek', 19),
#  ('catch', 19),
#  ('slide', 19),
#  ('flawlessly', 19),
#  ('five', 19),
#  ('missing', 19),
#  ('placed', 19),
#  ('daily', 19),
#  ('helpful', 19),
#  ('four', 19),
#  ('cumbersome', 19),
#  ('unplug', 19),
#  ('select', 19),
#  ('trash', 19),
#  ('generic', 19),
#  ('pop', 19),
#  ('stick', 19),
#  ('slot', 19),
#  ('camera', 19),
#  ('state', 19),
#  ('easiest', 18),
#  ('macbook', 18),
#  ('term', 18),
#  ('apparently', 18),
#  ('project', 18),
#  ('listed', 18),
#  ('chat', 18),
#  ('affordable', 18),
#  ('address', 18),
#  ('believe', 18),
#  ('sharp', 18),
#  ('delivery', 18),
#  ('crazy', 18),
#  ('wonderful', 18),
#  ('mind', 18),
#  ('disappointing', 18),
#  ('newer', 18),
#  ('previously', 18),
#  ('operating', 18),
#  ('signed', 18),
#  ('market', 18),
#  ('sample', 18),
#  ('lack', 18),
#  ('technology', 18),
#  ('changed', 18),
#  ('please', 18),
#  ('responsive', 18),
#  ('defective', 18),
#  ('amira', 18),
#  ('whatever', 17),
#  ('straight', 17),
#  ('mistake', 17),
#  ('cheaply', 17),
#  ('across', 17),
#  ('note', 17),
#  ('considering', 17),
#  ('port', 17),
#  ('following', 17),
#  ('produce', 17),
#  ('larger', 17),
#  ('telling', 17),
#  ('beyond', 17),
#  ('biggest', 17),
#  ('hoping', 17),
#  ('supply', 17),
#  ('require', 17),
#  ('unreliable', 17),
#  ('task', 17),
#  ('efficient', 17),
#  ('draft', 17),
#  ('similar', 17),
#  ('resolution', 17),
#  ('general', 17),
#  ('doc', 17),
#  ('package', 17),
#  ('unfortunately', 17),
#  ('odd', 17),
#  ('reinstall', 17),
#  ('glossy', 17),
#  ('photograph', 17),
#  ('dry', 17),
#  ('smartphone', 16),
#  ('lost', 16),
#  ('choose', 16),
#  ('material', 16),
#  ('reviewer', 16),
#  ('dell', 16),
#  ('student', 16),
#  ('thru', 16),
#  ('noisy', 16),
#  ('reconnect', 16),
#  ('solution', 16),
#  ('eventually', 16),
#  ('o', 16),
#  ('web', 16),
#  ('cause', 16),
#  ('attached', 16),
#  ('waiting', 16),
#  ('starter', 16),
#  ('rated', 16),
#  ('envy', 16),
#  ('seriously', 16),
#  ('pick', 16),
#  ('pulled', 16),
#  ('charm', 16),
#  ('entire', 16),
#  ('hassle', 16),
#  ('speak', 16),
#  ('connects', 16),
#  ('include', 16),
#  ('con', 16),
#  ('wasted', 16),
#  ('ton', 16),
#  ('various', 16),
#  ('insert', 16),
#  ('signal', 16),
#  ('enjoy', 16),
#  ('noise', 16),
#  ('avail', 16),
#  ('oh', 16),
#  ('attempt', 16),
#  ('finger', 16),
#  ('dvd', 16),
#  ('cool', 15),
#  ('technical', 15),
#  ('bright', 15),
#  ('separate', 15),
#  ('magenta', 15),
#  ('happen', 15),
#  ('live', 15),
#  ('refund', 15),
#  ('leave', 15),
#  ('fully', 15),
#  ('spot', 15),
#  ('opinion', 15),
#  ('honestly', 15),
#  ('latest', 15),
#  ('provide', 15),
#  ('manufacturer', 15),
#  ('expectation', 15),
#  ('bigger', 15),
#  ('documentation', 15),
#  ('realize', 15),
#  ('basically', 15),
#  ('excited', 15),
#  ('difference', 15),
#  ('application', 15),
#  ('prior', 15),
#  ('press', 15),
#  ('numerous', 15),
#  ('navigate', 15),
#  ('reinstalled', 15),
#  ('disconnect', 15),
#  ('cancel', 15),
#  ('accept', 15),
#  ('kid', 15),
#  ('door', 15),
#  ('nightmare', 15),
#  ('monthly', 15),
#  ('book', 15),
#  ('absolute', 15),
#  ('dislike', 15),
#  ('inside', 15),
#  ('chromebook', 15),
#  ('adf', 15),
#  ('fan', 15),
#  ('sound', 15),
#  ('io', 15),
#  ('saving', 15),
#  ('asked', 15),
#  ('gift', 15),
#  ('whether', 15),
#  ('comment', 15),
#  ('mainly', 15),
#  ('near', 14),
#  ('slightly', 14),
#  ('fair', 14),
#  ('prompt', 14),
#  ('awhile', 14),
#  ('miss', 14),
#  ('stand', 14),
#  ('taken', 14),
#  ('fixed', 14),
#  ('knew', 14),
#  ('sitting', 14),
#  ('everyone', 14),
#  ('mess', 14),
#  ('guy', 14),
#  ('keeping', 14),
#  ('reasonably', 14),
#  ('alone', 14),
#  ('incredibly', 14),
#  ('force', 14),
#  ('putting', 14),
#  ('future', 14),
#  ('moving', 14),
#  ('contacted', 14),
#  ('tiny', 14),
#  ('format', 14),
#  ('quit', 14),
#  ('storage', 14),
#  ('colored', 14),
#  ('foot', 14),
#  ('cart', 14),
#  ('rarely', 14),
#  ('floor', 14),
#  ('remember', 14),
#  ('headache', 14),
#  ('switch', 14),
#  ('throw', 14),
#  ('smoothly', 14),
#  ('pic', 14),
#  ('hopefully', 14),
#  ('upon', 14),
#  ('inch', 14),
#  ('functioning', 13),
#  ('continue', 13),
#  ('stupid', 13),
#  ('updated', 13),
#  ('weird', 13),
#  ('apps', 13),
#  ('remotely', 13),
#  ('late', 13),
#  ('search', 13),
#  ('truly', 13),
#  ('cyan', 13),
#  ('powered', 13),
#  ('worthless', 13),
#  ('upgraded', 13),
#  ('necessary', 13),
#  ('suggest', 13),
#  ('story', 13),
#  ('lift', 13),
#  ('happens', 13),
#  ('equipment', 13),
#  ('lcd', 13),
#  ('together', 13),
#  ('ten', 13),
#  ('location', 13),
#  ('bunch', 13),
#  ('flat', 13),
#  ('additional', 13),
#  ('sit', 13),
#  ('video', 13),
#  ('slowly', 13),
#  ('continues', 13),
#  ('consider', 13),
#  ('initially', 13),
#  ('ship', 13),
#  ('clearly', 13),
#  ('difficulty', 13),
#  ('ridiculous', 13),
#  ('smooth', 13),
#  ('worry', 13),
#  ('attractive', 13),
#  ('finding', 13),
#  ('position', 13),
#  ...]

# %%
freq3.plot(30)

# %% [markdown]
# # POS Tagging

# %% [markdown]
# Recall the notation:
# NN: Noun, singular or mass
# NNS: Noun, plural
# NNP: Proper noun, singular
# NNPS: Proper noun, plural

# %%
nltk.download('averaged_perceptron_tagger')

#Generate a list of POS tags
POS_tags = nltk.pos_tag(tokens) #use unprocessed 'tokens', not 'words'
POS_tags
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/isabelleliu/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('0', 'CD'),
#  (',', ','),
#  ("''", "''"),
#  ('this', 'DT'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('very', 'RB'),
#  ('well', 'RB'),
#  ('designed', 'VBN'),
#  ('great', 'JJ'),
#  ('looking', 'VBG'),
#  (',', ','),
#  ('great', 'JJ'),
#  ('functioning', 'VBG'),
#  ('printer', 'NN'),
#  ('except', 'IN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('very', 'RB'),
#  ('specific', 'JJ'),
#  ('way', 'NN'),
#  ('people', 'NNS'),
#  ('use', 'VBP'),
#  ('printer/scanners', 'NNS'),
#  ('these', 'DT'),
#  ('days', 'NNS'),
#  ('.', '.'),
#  ('i', 'NN'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('print', 'VB'),
#  ('as', 'RB'),
#  ('much', 'JJ'),
#  (',', ','),
#  ('but', 'CC'),
#  ('i', 'JJ'),
#  ('scan', 'VBP'),
#  ('A', 'DT'),
#  ('LOT', 'NNP'),
#  ('.', '.'),
#  ('and', 'CC'),
#  ('when', 'WRB'),
#  ('i', 'JJ'),
#  ('scan', 'VBP'),
#  (',', ','),
#  ('i', 'JJ'),
#  ('scan', 'VBP'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('printer', 'NN'),
#  ('direct', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('computer', 'NN'),
#  ('and', 'CC'),
#  ('then', 'RB'),
#  ('go', 'VB'),
#  ('back', 'RB'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('computer', 'NN'),
#  ('and', 'CC'),
#  ('organize', 'VB'),
#  ('all', 'PDT'),
#  ('the', 'DT'),
#  ('scanned', 'VBN'),
#  ('docs.this', 'NN'),
#  ('printer', 'NN'),
#  ('does', 'VBZ'),
#  ('not', 'RB'),
#  ('have', 'VB'),
#  ('that', 'DT'),
#  ('functionality', 'NN'),
#  ('for', 'IN'),
#  ('Macs', 'NNP'),
#  ('yet', 'RB'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('workaround', 'NN'),
#  ('is', 'VBZ'),
#  ('to', 'TO'),
#  ('scan', 'VB'),
#  ('to', 'TO'),
#  ('your', 'PRP$'),
#  ('email', 'NN'),
#  ('(', '('),
#  ('convoluted', 'VBN'),
#  ('&', 'CC'),
#  ('clumsy', 'VBN'),
#  (')', ')'),
#  ('or', 'CC'),
#  ('use', 'VB'),
#  ('their', 'PRP$'),
#  ('mobile', 'JJ'),
#  ('app', 'NN'),
#  ('(', '('),
#  ('less', 'RBR'),
#  ('convoluted', 'VBN'),
#  ('&', 'CC'),
#  ('clumsy', 'JJ'),
#  (',', ','),
#  ('but', 'CC'),
#  ('still', 'RB'),
#  ('aggravating', 'VBG'),
#  (')', ')'),
#  ('.', '.'),
#  ('these', 'DT'),
#  ('are', 'VBP'),
#  ('their', 'PRP$'),
#  ('new', 'JJ'),
#  ('top', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('line', 'NN'),
#  (',', ','),
#  ('not-cheap', 'JJ'),
#  ('models', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('they', 'PRP'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('have', 'VB'),
#  ('the', 'DT'),
#  ('most', 'JJS'),
#  ('basic', 'JJ'),
#  ('functionality', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('way', 'NN'),
#  ('people', 'NNS'),
#  ('work', 'VBP'),
#  ('today', 'NN'),
#  ('.', '.'),
#  ('my', 'PRP$'),
#  ('printer', 'NN'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('near', 'IN'),
#  ('my', 'PRP$'),
#  ('computer', 'NN'),
#  (',', ','),
#  ('they', 'PRP'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('need', 'VB'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('anymore', 'RB'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('is', 'VBZ'),
#  ('why', 'WRB'),
#  ('i', 'NN'),
#  ('like', 'IN'),
#  ('being', 'VBG'),
#  ('able', 'JJ'),
#  ('to', 'TO'),
#  ('scan', 'VB'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('printer', 'NN'),
#  ('itself.after', 'NN'),
#  ('searching', 'VBG'),
#  ('online', 'NN'),
#  ('and', 'CC'),
#  ('chatting', 'VBG'),
#  ('with', 'IN'),
#  ('HP', 'NNP'),
#  ('support', 'NN'),
#  (',', ','),
#  ('i', 'VB'),
#  ('finally', 'RB'),
#  ('spoke', 'VBN'),
#  ('to', 'TO'),
#  ('someone', 'NN'),
#  ('after', 'IN'),
#  ('going', 'VBG'),
#  ('through', 'IN'),
#  ('their', 'PRP$'),
#  ('terrible', 'JJ'),
#  ('automated', 'VBN'),
#  ('customer', 'NN'),
#  ('service', 'NN'),
#  ('line', 'NN'),
#  ('.', '.'),
#  ('he', 'PRP'),
#  ('said', 'VBD'),
#  ('the', 'DT'),
#  ('functionality', 'NN'),
#  ('will', 'MD'),
#  ('come', 'VB'),
#  (',', ','),
#  ('but', 'CC'),
#  ('they', 'PRP'),
#  ('have', 'VBP'),
#  ("n't", 'RB'),
#  ('finished', 'VBN'),
#  ('the', 'DT'),
#  ('software', 'NN'),
#  ('for', 'IN'),
#  ('it', 'PRP'),
#  ('yet', 'RB'),
#  ('.', '.'),
#  ('i', 'NN'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('know', 'VB'),
#  ('when', 'WRB'),
#  ('that', 'DT'),
#  ('day', 'NN'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  (',', ','),
#  ('so', 'IN'),
#  ('if', 'IN'),
#  ('you', 'PRP'),
#  ('need', 'VBP'),
#  ('to', 'TO'),
#  ('scan', 'VB'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('printer', 'NN'),
#  ('direct', 'JJ'),
#  ('to', 'TO'),
#  ('your', 'PRP$'),
#  ('Mac', 'NNP'),
#  ('and', 'CC'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('want', 'VB'),
#  ('to', 'TO'),
#  ('do', 'VB'),
#  ('the', 'DT'),
#  ('clumsy', 'NN'),
#  ('workaround', 'NN'),
#  ('DO', 'NNP'),
#  ('NOT', 'NNP'),
#  ('BUY', 'VB'),
#  ('THIS', 'NNP'),
#  ('PRINTER.i', 'NNP'),
#  ("'ll", 'MD'),
#  ('update', 'VB'),
#  ('my', 'PRP$'),
#  ('review', 'NN'),
#  ('when', 'WRB'),
#  ('HP', 'NNP'),
#  ('updates', 'VBZ'),
#  ('their', 'PRP$'),
#  ('software', 'NN'),
#  ('.', '.'),
#  ("''", "''"),
#  ('1', 'CD'),
#  (',', ','),
#  ("''", "''"),
#  ('This', 'DT'),
#  ('printer', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('really', 'RB'),
#  ('small', 'JJ'),
#  (',', ','),
#  ('but', 'CC'),
#  ('with', 'IN'),
#  ('lots', 'NNS'),
#  ('of', 'IN'),
#  ('features', 'NNS'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('really', 'RB'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('have', 'VB'),
#  ('lot', 'NN'),
#  ('of', 'IN'),
#  ('space', 'NN'),
#  ('in', 'IN'),
#  ('my', 'PRP$'),
#  ('office', 'NN'),
#  (',', ','),
#  ('so', 'IN'),
#  ('this', 'DT'),
#  ('printer', 'NN'),
#  ('fits', 'VBZ'),
#  ('perfectly', 'RB'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('plugged', 'VBD'),
#  ('into', 'IN'),
#  ('my', 'PRP$'),
#  ('computer', 'NN'),
#  ('(', '('),
#  ('Windows', 'NNP'),
#  ('10', 'CD'),
#  (')', ')'),
#  ('and', 'CC'),
#  ('it', 'PRP'),
#  ('detected', 'VBD'),
#  ('and', 'CC'),
#  ('installed', 'VBD'),
#  ('the', 'DT'),
#  ('required', 'JJ'),
#  ('drivers', 'NNS'),
#  ('automatically', 'RB'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('could', 'MD'),
#  ('printed', 'VB'),
#  ('few', 'JJ'),
#  ('pages', 'NNS'),
#  ('in', 'IN'),
#  ('no', 'DT'),
#  ('time', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('I', 'PRP'),
#  ('can', 'MD'),
#  ('tell', 'VB'),
#  ('you', 'PRP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('print', 'NN'),
#  ('quality', 'NN'),
#  ('is', 'VBZ'),
#  ('excellent', 'JJ'),
#  (',', ','),
#  ('and', 'CC'),
#  ('its', 'PRP$'),
#  ('very', 'RB'),
#  ('quiet', 'JJ'),
#  ('when', 'WRB'),
#  ('printing', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('was', 'VBD'),
#  ('also', 'RB'),
#  ('able', 'JJ'),
#  ('to', 'TO'),
#  ('connect', 'VB'),
#  ('to', 'TO'),
#  ('my', 'PRP$'),
#  ('smartphone', 'NN'),
#  ('(', '('),
#  ('Samsung', 'NNP'),
#  ('Galaxy', 'NNP'),
#  ('S10', 'NNP'),
#  (')', ')'),
#  ('and', 'CC'),
#  ('print', 'VB'),
#  ('a', 'DT'),
#  ('document', 'NN'),
#  ('from', 'IN'),
#  ('my', 'PRP$'),
#  ('phone', 'NN'),
#  ('directly', 'RB'),
#  (',', ','),
#  ('is', 'VBZ'),
#  ("n't", 'RB'),
#  ('that', 'DT'),
#  ('cool', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('printer', 'NN'),
#  ('came', 'VBD'),
#  ('with', 'IN'),
#  ('few', 'JJ'),
#  ('cartridges', 'NNS'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('scanned', 'VBD'),
#  ('few', 'JJ'),
#  ('4x6', 'CD'),
#  ('postcard', 'NN'),
#  ('photos', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('OMG', 'NNP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('scanned', 'JJ'),
#  ('photos', 'NNS'),
#  ('look', 'VBP'),
#  ('better', 'JJR'),
#  ('than', 'IN'),
#  ('the', 'DT'),
#  ('original', 'JJ'),
#  ('printed', 'JJ'),
#  ('photo', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('been', 'VBN'),
#  ('looking', 'VBG'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('good', 'JJ'),
#  ('scanner', 'NN'),
#  ('to', 'TO'),
#  ('convert', 'VB'),
#  ('all', 'DT'),
#  ('my', 'PRP$'),
#  ('old', 'JJ'),
#  ('4x6', 'CD'),
#  ('photos', 'NN'),
#  ('to', 'TO'),
#  ('digital', 'VB'),
#  (',', ','),
#  ('and', 'CC'),
#  ('this', 'DT'),
#  ('is', 'VBZ'),
#  ('it', 'PRP'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('know', 'VBP'),
#  ('what', 'WP'),
#  ('I', 'PRP'),
#  ('am', 'VBP'),
#  ('doing', 'VBG'),
#  ('this', 'DT'),
#  ('weekend', 'NN'),
#  ('.', '.'),
#  ('And', 'CC'),
#  (',', ','),
#  ('btw', 'NN'),
#  (',', ','),
#  ('unlike', 'IN'),
#  ('my', 'PRP$'),
#  ('old', 'JJ'),
#  ('scanner', 'NN'),
#  (',', ','),
#  ('this', 'DT'),
#  ('does', 'VBZ'),
#  ("n't", 'RB'),
#  ('take', 'VB'),
#  ('lot', 'NN'),
#  ('of', 'IN'),
#  ('time', 'NN'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('took', 'VBD'),
#  ('may', 'MD'),
#  ('be', 'VB'),
#  ('1.5', 'CD'),
#  ('seconds', 'NNS'),
#  ('to', 'TO'),
#  ('scan', 'VB'),
#  ('a', 'DT'),
#  ('photo', 'NN'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('is', 'VBZ'),
#  ('fairly', 'RB'),
#  ('quick', 'JJ'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('yet', 'RB'),
#  ('to', 'TO'),
#  ('try', 'VB'),
#  ('other', 'JJ'),
#  ('features', 'NNS'),
#  (',', ','),
#  ('but', 'CC'),
#  ('I', 'PRP'),
#  ('am', 'VBP'),
#  ('already', 'RB'),
#  ('blown', 'VBN'),
#  ('away', 'RB'),
#  ('by', 'IN'),
#  ('this', 'DT'),
#  ('printer', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('will', 'MD'),
#  ('continue', 'VB'),
#  ('to', 'TO'),
#  ('explore', 'VB'),
#  ('and', 'CC'),
#  ('update', 'VB'),
#  ('the', 'DT'),
#  ('review', 'NN'),
#  ('.', '.'),
#  ('So', 'RB'),
#  ('far', 'RB'),
#  (',', ','),
#  ('my', 'PRP$'),
#  ('favorite', 'JJ'),
#  ('feature', 'NN'),
#  ('is', 'VBZ'),
#  ('mobile', 'JJ'),
#  ('printing', 'NN'),
#  ('.', '.'),
#  ("''", "''"),
#  ('2', 'CD'),
#  (',', ','),
#  ("''", "''"),
#  ('I', 'PRP'),
#  ('had', 'VBD'),
#  ('to', 'TO'),
#  ('buy', 'VB'),
#  ('a', 'DT'),
#  ('printer', 'NN'),
#  ('after', 'IN'),
#  ('my', 'PRP$'),
#  ('second', 'JJ'),
#  ('Canon', 'NNP'),
#  ('became', 'VBD'),
#  ('a', 'DT'),
#  ('brick', 'NN'),
#  ('after', 'IN'),
#  ('less', 'JJR'),
#  ('than', 'IN'),
#  ('2', 'CD'),
#  ('years', 'NNS'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('did', 'VBD'),
#  ('my', 'PRP$'),
#  ('research', 'NN'),
#  ('to', 'TO'),
#  ('find', 'VB'),
#  ('the', 'DT'),
#  ('best', 'JJS'),
#  ('one', 'CD'),
#  ('out', 'IN'),
#  ('there', 'RB'),
#  ('at', 'IN'),
#  ('my', 'PRP$'),
#  ('price', 'NN'),
#  ('point', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('bought', 'VBD'),
#  ('this', 'DT'),
#  ('HP', 'NNP'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('had', 'VBD'),
#  ('HP', 'NNP'),
#  ('printers', 'NNS'),
#  ('for', 'IN'),
#  ('years', 'NNS'),
#  ('and', 'CC'),
#  ('was', 'VBD'),
#  ('always', 'RB'),
#  ('happy', 'JJ'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('print', 'NN'),
#  ('quality', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('I', 'PRP'),
#  ('stopped', 'VBD'),
#  ('buying', 'VBG'),
#  ('them', 'PRP'),
#  ('because', 'IN'),
#  ('their', 'PRP$'),
#  ('software', 'NN'),
#  ('was', 'VBD'),
#  ('so', 'RB'),
#  ('stupid', 'JJ'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ("'ve", 'VBP'),
#  ('thankfully', 'RB'),
#  ('addressed', 'VBN'),
#  ('that', 'IN'),
#  ('issue.This', 'NN'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('fourth', 'JJ'),
#  ('time', 'NN'),
#  ('I', 'PRP'),
#  ("'ve", 'VBP'),
#  ('updated', 'VBN'),
#  ('my', 'PRP$'),
#  ('review', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('started', 'VBD'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('3-star', 'JJ'),
#  (',', ','),
#  ('then', 'RB'),
#  ('went', 'VBD'),
#  ('to', 'TO'),
#  ('4', 'CD'),
#  (',', ','),
#  ('then', 'RB'),
#  ('went', 'VBD'),
#  ('to', 'TO'),
#  ('5', 'CD'),
#  (',', ','),
#  ('then', 'RB'),
#  ('down', 'RB'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('2', 'CD'),
#  ('(', '('),
#  ('yeow', 'NN'),
#  (')', ')'),
#  (',', ','),
#  ('but', 'CC'),
#  ('now', 'RB'),
#  ('it', 'PRP'),
#  ("'s", 'VBZ'),
#  ('back', 'RB'),
#  ('to', 'TO'),
#  ('5', 'CD'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ("'", 'POS'),
#  ('2', 'CD'),
#  ("'", "''"),
#  ('rating', 'NN'),
#  ('was', 'VBD'),
#  ('due', 'JJ'),
#  ('to', 'TO'),
#  ('significant', 'JJ'),
#  ('network', 'NN'),
#  ('instability', 'NN'),
#  ('.', '.'),
#  ('Everything', 'NN'),
#  ('else', 'RB'),
#  ('on', 'IN'),
#  ('my', 'PRP$'),
#  ('network', 'NN'),
#  ('seemed', 'VBD'),
#  ('to', 'TO'),
#  ('work', 'VB'),
#  ('fine', 'JJ'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('new', 'JJ'),
#  ('TPLink', 'NNP'),
#  ('wireless', 'NN'),
#  ('router', 'NN'),
#  ('except', 'IN'),
#  ('this', 'DT'),
#  ('printer', 'NN'),
#  ('.', '.'),
#  ('Shortly', 'RB'),
#  ('after', 'IN'),
#  ('giving', 'VBG'),
#  ('the', 'DT'),
#  ('printer', 'NN'),
#  ('a', 'DT'),
#  ('2', 'CD'),
#  ('rating', 'NN'),
#  ('I', 'PRP'),
#  ('detected', 'VBD'),
#  ('some', 'DT'),
#  ('weird', 'JJ'),
#  ('happenings', 'NNS'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('router', 'NN'),
#  ('.', '.'),
#  ('After', 'IN'),
#  ('talking', 'VBG'),
#  ('to', 'TO'),
#  ('their', 'PRP$'),
#  ('tech', 'JJ'),
#  ('support', 'NN'),
#  ('and', 'CC'),
#  ('doing', 'VBG'),
#  ('some', 'DT'),
#  ('changes', 'NNS'),
#  (',', ','),
#  ('the', 'DT'),
#  ('router', 'NN'),
#  ('worked', 'VBD'),
#  ('much', 'RB'),
#  ('better', 'RBR'),
#  ('.', '.'),
#  ('Amazingly', 'RB'),
#  ('the', 'DT'),
#  ('printer', 'NN'),
#  ('has', 'VBZ'),
#  ("n't", 'RB'),
#  ('lost', 'VBN'),
#  ('connection', 'NN'),
#  ('since', 'IN'),
#  ('then', 'RB'),
#  (',', ','),
#  ('and', 'CC'),
#  ('it', 'PRP'),
#  ("'s", 'VBZ'),
#  ('been', 'VBN'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('a', 'DT'),
#  ('month.The', 'JJ'),
#  ('print', 'NN'),
#  ('quality', 'NN'),
#  ('and', 'CC'),
#  ('speed', 'NN'),
#  ('are', 'VBP'),
#  ('great', 'JJ'),
#  (',', ','),
#  ('and', 'CC'),
#  ('it', 'PRP'),
#  ('works', 'VBZ'),
#  ('equally', 'RB'),
#  ('fine', 'JJ'),
#  ('with', 'IN'),
#  ('my', 'PRP$'),
#  ('Win10', 'NNP'),
#  (',', ','),
#  ('Linux', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('iPad', 'VB'),
#  ('systems.One', 'NN'),
#  ('other', 'JJ'),
#  ('feature', 'NN'),
#  ('that', 'IN'),
#  ('I', 'PRP'),
#  ('just', 'RB'),
#  ('started', 'VBD'),
#  ('using', 'VBG'),
#  ('(', '('),
#  ('8/27/19', 'CD'),
#  (')', ')'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('document', 'NN'),
#  ('feeder', 'NN'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('home', 'NN'),
#  ('printer', 'NN'),
#  ('I', 'PRP'),
#  ("'ve", 'VBP'),
#  ('had', 'VBN'),
#  ('with', 'IN'),
#  ('that', 'DT'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('sure', 'JJ'),
#  ('beats', 'VBZ'),
#  ('doing', 'VBG'),
#  ('a', 'DT'),
#  ('5', 'CD'),
#  ('page', 'NN'),
#  ('scan', 'JJ'),
#  ('and', 'CC'),
#  ('standing', 'VBG'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('printer', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('only', 'JJ'),
#  ('issue', 'NN'),
#  ('is', 'VBZ'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('feed', 'NN'),
#  ('into', 'IN'),
#  ('the', 'DT'),
#  ('scanner', 'NN'),
#  ('is', 'VBZ'),
#  ('slightly', 'RB'),
#  ('ajar', 'JJ'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ("'ve", 'VBP'),
#  ('checked', 'VBN'),
#  ('the', 'DT'),
#  ('option', 'NN'),
#  ('to', 'TO'),
#  ('align', 'VB'),
#  ('the', 'DT'),
#  ('scan', 'JJ'),
#  ('but', 'CC'),
#  ('it', 'PRP'),
#  ('did', 'VBD'),
#  ("n't", 'RB'),
#  ('seem', 'VB'),
#  ('to', 'TO'),
#  ('help', 'VB'),
#  ('.', '.'),
#  ('Still', 'RB'),
#  (',', ','),
#  ('I', 'PRP'),
#  ("'ll", 'MD'),
#  ('put', 'VB'),
#  ('up', 'RP'),
#  ('with', 'IN'),
#  ('minimally', 'RB'),
#  ('wonky', 'JJ'),
#  ('scans', 'NNS'),
#  ('if', 'IN'),
#  ('I', 'PRP'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('have', 'VB'),
#  ('to', 'TO'),
#  ('manually', 'RB'),
#  ('feed', 'VB'),
#  ('it', 'PRP'),
#  ('in', 'IN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('feeder', 'NN'),
#  ('also', 'RB'),
#  ('works', 'VBZ'),
#  ('for', 'IN'),
#  ('copies', 'NNS'),
#  (',', ','),
#  ('so', 'RB'),
#  ('cool.Now', 'JJ'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('security', 'NN'),
#  ('concerns', 'NNS'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ("'m", 'VBP'),
#  ('not', 'RB'),
#  ('sure', 'JJ'),
#  ('what', 'WP'),
#  ('they', 'PRP'),
#  ('were', 'VBD'),
#  ('thinking', 'VBG'),
#  ('when', 'WRB'),
#  ('they', 'PRP'),
#  ('designed', 'VBD'),
#  ('the', 'DT'),
#  ('printer', 'NN'),
#  ('to', 'TO'),
#  ('have', 'VB'),
#  ('its', 'PRP$'),
#  ('own', 'JJ'),
#  ('WiFi', 'NNP'),
#  ('in', 'IN'),
#  ('addition', 'NN'),
#  ('to', 'TO'),
#  ('connecting', 'VBG'),
#  ('to', 'TO'),
#  ('my', 'PRP$'),
#  ('WiFi', 'NNP'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ("'s", 'VBZ'),
#  ('like', 'IN'),
#  ('they', 'PRP'),
#  ("'re", 'VBP'),
#  ('circumventing', 'VBG'),
#  ('my', 'PRP$'),
#  ('security', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('need', 'VB'),
#  ('their', 'PRP$'),
#  ('WiFi', 'NNP'),
#  ('for', 'IN'),
#  ('whatever', 'WDT'),
#  ('purposes', 'NNS'),
#  ('it', 'PRP'),
#  ('serves', 'VBZ'),
#  ('.', '.'),
#  ('My', 'PRP$'),
#  ('big', 'JJ'),
#  ('complaint', 'NN'),
#  ('is', 'VBZ'),
#  ('that', 'IN'),
#  ('this', 'DT'),
#  ('should', 'MD'),
#  ('have', 'VB'),
#  ('been', 'VBN'),
#  ('a', 'DT'),
#  ('simple', 'JJ'),
#  ('yes/no', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('printer', 'NN'),
#  ('setup', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('had', 'VBD'),
#  ('to', 'TO'),
#  ('go', 'VB'),
#  ('find', 'VB'),
#  ('it', 'PRP'),
#  ('to', 'TO'),
#  ('turn', 'VB'),
#  ('it', 'PRP'),
#  ('off.The', 'RP'),
#  ('second', 'JJ'),
#  ('concern', 'NN'),
#  ('is', 'VBZ'),
#  ('that', 'IN'),
#  ('they', 'PRP'),
#  ('send', 'VBP'),
#  ('technical', 'JJ'),
#  ('diagnostic', 'JJ'),
#  ('info', 'NN'),
#  ('back', 'RB'),
#  ('to', 'TO'),
#  ('HP', 'NNP'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('say', 'VBP'),
#  ('there', 'EX'),
#  ("'s", 'VBZ'),
#  ('no', 'DT'),
#  ('identifying', 'JJ'),
#  ('information', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('care', 'VB'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('do', 'VBP'),
#  ("n't", 'RB'),
#  ('want', 'VB'),
#  ('any', 'DT'),
#  ('info', 'NN'),
#  ('leaving', 'VBG'),
#  ('my', 'PRP$'),
#  ('network', 'NN'),
#  ('unless', 'IN'),
#  ('I', 'PRP'),
#  ('initiate', 'VBP'),
#  ('it', 'PRP'),
#  ('.', '.'),
#  ('Once', 'RB'),
#  ('again', 'RB'),
#  (',', ','),
#  ('this', 'DT'),
#  ('should', 'MD'),
#  ('have', 'VB'),
#  ('been', 'VBN'),
#  ('a', 'DT'),
#  ('simple', 'JJ'),
#  ('yes/no', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('printer', 'NN'),
#  ('setup', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('I', 'PRP'),
#  ('had', 'VBD'),
#  ('to', 'TO'),
#  ('go', 'VB'),
#  ('find', 'RB'),
#  ('it.Lastly', 'RB'),
#  (',', ','),
#  ('not', 'RB'),
#  ('really', 'RB'),
#  ('an', 'DT'),
#  ('HP', 'NNP'),
#  ('issue', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('the', 'DT'),
#  ('HP', 'NNP'),
#  ('iPhone', 'NN'),
#  ('app', 'NN'),
#  ('setup', 'NN'),
#  ('allowed', 'VBD'),
#  ('the', 'DT'),
#  ('printer', 'NN'),
#  ('to', 'TO'),
#  ('pull', 'VB'),
#  ('off', 'RP'),
#  ('my', 'PRP$'),
#  ('networks', 'NNS'),
#  ('SSID', 'NNP'),
#  ('and', 'CC'),
#  ('password', 'NN'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('iPhone', 'NN'),
#  ('and', 'CC'),
#  ('store', 'NN'),
#  ('it', 'PRP'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('printer', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('had', 'VBD'),
#  ('no', 'DT'),
#  ('idea', 'NN'),
#  ('that', 'IN'),
#  ('an', 'DT'),
#  ...]

# %%
#Keep tags that start with 'N'
POS_tag_listN = [(word,tag) for (word,tag) in POS_tags if tag.startswith('N')]

# %%
#Generate a frequency distribution 
tag_freq = nltk.FreqDist(POS_tag_listN)
sorted_tag_freq = sorted(tag_freq.items(), key = lambda k:k[1], reverse = True)
sorted_tag_freq
# Out:
# [(('printer', 'NN'), 3674),
#  (('ink', 'NN'), 1084),
#  (('paper', 'NN'), 846),
#  (('HP', 'NNP'), 816),
#  (('Canon', 'NNP'), 659),
#  (('quality', 'NN'), 655),
#  (('print', 'NN'), 592),
#  (('time', 'NN'), 513),
#  (('printing', 'NN'), 504),
#  (('cartridges', 'NNS'), 384),
#  (('printers', 'NNS'), 364),
#  (('price', 'NN'), 328),
#  (('tray', 'NN'), 319),
#  (('computer', 'NN'), 311),
#  (('home', 'NN'), 283),
#  (('phone', 'NN'), 269),
#  (('color', 'NN'), 257),
#  (('support', 'NN'), 235),
#  (('pages', 'NNS'), 226),
#  (('wireless', 'NN'), 226),
#  (('use', 'NN'), 223),
#  (('product', 'NN'), 221),
#  (('’', 'NNP'), 217),
#  (('prints', 'NNS'), 212),
#  (('setup', 'NN'), 211),
#  (('page', 'NN'), 207),
#  (('t', 'NN'), 200),
#  (('software', 'NN'), 196),
#  (('problem', 'NN'), 193),
#  (('cartridge', 'NN'), 186),
#  (('years', 'NNS'), 184),
#  (('months', 'NNS'), 184),
#  (('photo', 'NN'), 180),
#  (('Great', 'NNP'), 180),
#  (('screen', 'NN'), 178),
#  (('thing', 'NN'), 178),
#  (('error', 'NN'), 177),
#  (('lot', 'NN'), 174),
#  (('app', 'NN'), 171),
#  (('Easy', 'NNP'), 170),
#  (('office', 'NN'), 163),
#  (('connection', 'NN'), 161),
#  (('network', 'NN'), 158),
#  (('way', 'NN'), 156),
#  (('issues', 'NNS'), 156),
#  (('documents', 'NNS'), 145),
#  (('machine', 'NN'), 142),
#  (('scanner', 'NN'), 141),
#  (('problems', 'NNS'), 141),
#  (('something', 'NN'), 140),
#  (('everything', 'NN'), 139),
#  (('model', 'NN'), 137),
#  (('times', 'NNS'), 137),
#  (('issue', 'NN'), 136),
#  (('work', 'NN'), 135),
#  (('photos', 'NNS'), 132),
#  (('Amazon', 'NNP'), 132),
#  (('instructions', 'NNS'), 129),
#  (('size', 'NN'), 127),
#  (('money', 'NN'), 125),
#  (('Printer', 'NNP'), 125),
#  (('replacement', 'NN'), 120),
#  (('box', 'NN'), 120),
#  (('one', 'NN'), 116),
#  (('minutes', 'NNS'), 115),
#  (('days', 'NNS'), 113),
#  (('features', 'NNS'), 109),
#  (('reviews', 'NNS'), 109),
#  (('bit', 'NN'), 107),
#  (('document', 'NN'), 106),
#  (('job', 'NN'), 105),
#  (('USB', 'NNP'), 104),
#  (('hours', 'NNS'), 102),
#  (('anything', 'NN'), 99),
#  (('Print', 'NNP'), 98),
#  (('things', 'NNS'), 98),
#  (('copies', 'NNS'), 97),
#  (('TS9120', 'NNP'), 97),
#  (('year', 'NN'), 95),
#  (('WiFi', 'NNP'), 93),
#  (('wifi', 'NN'), 93),
#  (('message', 'NN'), 92),
#  (('month', 'NN'), 92),
#  (('service', 'NN'), 91),
#  (('drivers', 'NNS'), 91),
#  (('nothing', 'NN'), 90),
#  (('day', 'NN'), 89),
#  (('feature', 'NN'), 89),
#  (('cost', 'NN'), 89),
#  (('device', 'NN'), 84),
#  (('brand', 'NN'), 80),
#  (('Ink', 'NNP'), 80),
#  (('purchase', 'NN'), 80),
#  (('set', 'NN'), 79),
#  (('Epson', 'NNP'), 78),
#  (('cable', 'NN'), 77),
#  (('laptop', 'NN'), 75),
#  (('speed', 'NN'), 72),
#  (('piece', 'NN'), 72),
#  (('jam', 'NN'), 71),
#  (('i', 'NN'), 70),
#  (('review', 'NN'), 70),
#  (('fax', 'NN'), 70),
#  (('process', 'NN'), 69),
#  (('reason', 'NN'), 68),
#  (('order', 'NN'), 67),
#  (('Love', 'NNP'), 67),
#  (('feeder', 'NN'), 66),
#  (('NOT', 'NNP'), 65),
#  (('panel', 'NN'), 65),
#  (('option', 'NN'), 64),
#  (('stars', 'NNS'), 64),
#  (('unit', 'NN'), 64),
#  (('needs', 'NNS'), 63),
#  (('settings', 'NNS'), 63),
#  (('driver', 'NN'), 62),
#  (('router', 'NN'), 61),
#  (('pictures', 'NNS'), 61),
#  (('business', 'NN'), 60),
#  (('help', 'NN'), 60),
#  (('program', 'NN'), 60),
#  (('products', 'NNS'), 60),
#  (('scanning', 'NN'), 60),
#  (('power', 'NN'), 60),
#  (('line', 'NN'), 59),
#  (('Windows', 'NNP'), 59),
#  (('trouble', 'NN'), 59),
#  (('toner', 'NN'), 59),
#  (('photos', 'NN'), 58),
#  (('weeks', 'NNS'), 58),
#  (('customer', 'NN'), 57),
#  (('devices', 'NNS'), 56),
#  (('sheets', 'NNS'), 56),
#  (('point', 'NN'), 55),
#  (('hour', 'NN'), 55),
#  (('function', 'NN'), 55),
#  (('options', 'NNS'), 55),
#  (('PC', 'NN'), 55),
#  (('Mac', 'NNP'), 54),
#  (('couple', 'NN'), 54),
#  (('part', 'NN'), 54),
#  (('deal', 'NN'), 54),
#  (('iPhone', 'NN'), 53),
#  (('copy', 'NN'), 53),
#  (('installation', 'NN'), 53),
#  (('OfficeJet', 'NNP'), 52),
#  (('fact', 'NN'), 52),
#  (('number', 'NN'), 52),
#  (('Brother', 'NNP'), 52),
#  (('space', 'NN'), 51),
#  (('website', 'NN'), 51),
#  (('people', 'NNS'), 50),
#  (('feed', 'NN'), 50),
#  (('Pro', 'NNP'), 50),
#  (('output', 'NN'), 48),
#  (('code', 'NN'), 48),
#  (('Cannon', 'NNP'), 48),
#  (('room', 'NN'), 47),
#  (('inks', 'NNS'), 47),
#  (('laser', 'NN'), 47),
#  (('side', 'NN'), 46),
#  (('Setup', 'NNP'), 46),
#  (('button', 'NN'), 46),
#  (('Good', 'NNP'), 46),
#  (('colors', 'NNS'), 45),
#  (('Bluetooth', 'NNP'), 45),
#  (('Paper', 'NNP'), 44),
#  (('s', 'NN'), 44),
#  (('%', 'NN'), 44),
#  (('week', 'NN'), 44),
#  (('design', 'NN'), 44),
#  (('experience', 'NN'), 44),
#  (('inkjet', 'NN'), 44),
#  (('test', 'NN'), 44),
#  (('desk', 'NN'), 44),
#  (('copier', 'NN'), 43),
#  (('picture', 'NN'), 43),
#  (('jams', 'NNS'), 43),
#  (('system', 'NN'), 43),
#  (('life', 'NN'), 42),
#  (('Wireless', 'NNP'), 42),
#  (('plastic', 'NN'), 42),
#  (('Prints', 'NNS'), 42),
#  (('end', 'NN'), 42),
#  (('mode', 'NN'), 42),
#  (('text', 'NN'), 42),
#  (('jobs', 'NNS'), 41),
#  (('star', 'NN'), 41),
#  (('Nice', 'NNP'), 41),
#  (('junk', 'NN'), 40),
#  (('value', 'NN'), 40),
#  (('while', 'NN'), 40),
#  (('user', 'NN'), 39),
#  (('First', 'NNP'), 39),
#  (('Very', 'NNP'), 39),
#  (('item', 'NN'), 39),
#  (('return', 'NN'), 39),
#  (('house', 'NN'), 38),
#  (('images', 'NNS'), 38),
#  (('others', 'NNS'), 38),
#  (('IT', 'NNP'), 38),
#  (('plan', 'NN'), 37),
#  (('t', 'NNS'), 37),
#  (('front', 'NN'), 36),
#  (('ability', 'NN'), 36),
#  (('Pixma', 'NNP'), 36),
#  (('tech', 'NN'), 36),
#  (('cord', 'NN'), 36),
#  (('computers', 'NNS'), 35),
#  (('functions', 'NNS'), 35),
#  (('garbage', 'NN'), 35),
#  (('top', 'NN'), 34),
#  (('scans', 'NNS'), 34),
#  (('pain', 'NN'), 34),
#  (('company', 'NN'), 34),
#  (('anyone', 'NN'), 34),
#  (('tablet', 'NN'), 34),
#  (('warranty', 'NN'), 34),
#  (('online', 'NN'), 33),
#  (('course', 'NN'), 33),
#  (('Apple', 'NNP'), 33),
#  (('works', 'NNS'), 33),
#  (('card', 'NN'), 33),
#  (('breeze', 'NN'), 32),
#  (('image', 'NN'), 32),
#  (('control', 'NN'), 32),
#  (('Just', 'NNP'), 32),
#  (('Works', 'NNP'), 32),
#  (('connectivity', 'NN'), 31),
#  (('My', 'NNP'), 31),
#  (('kind', 'NN'), 31),
#  (('”', 'NNP'), 31),
#  (('CD', 'NN'), 31),
#  (('someone', 'NN'), 30),
#  (('research', 'NN'), 30),
#  (('person', 'NN'), 30),
#  (('Set', 'NNP'), 30),
#  (('wife', 'NN'), 30),
#  (('school', 'NN'), 30),
#  (('need', 'NN'), 30),
#  (('A', 'NNP'), 30),
#  (('version', 'NN'), 30),
#  (('today', 'NN'), 29),
#  (('THIS', 'NNP'), 29),
#  (('Support', 'NNP'), 29),
#  (('hp', 'NN'), 29),
#  (('touch', 'NN'), 29),
#  (('footprint', 'NN'), 29),
#  (('canon', 'NN'), 29),
#  (('internet', 'NN'), 29),
#  (('shipping', 'NN'), 29),
#  (('Visitor', 'NN'), 29),
#  (('information', 'NN'), 28),
#  (('iPad', 'NN'), 28),
#  (('series', 'NN'), 28),
#  (('desktop', 'NN'), 28),
#  (('head', 'NN'), 28),
#  (('access', 'NN'), 28),
#  (('capability', 'NN'), 28),
#  (('stuff', 'NN'), 28),
#  (('Google', 'NNP'), 28),
#  (('steps', 'NNS'), 28),
#  (('type', 'NN'), 28),
#  (('window', 'NN'), 28),
#  (('tanks', 'NNS'), 28),
#  (('look', 'NN'), 28),
#  (('models', 'NNS'), 27),
#  (('lots', 'NNS'), 27),
#  (('idea', 'NN'), 27),
#  (('Best', 'NNP'), 27),
#  (('Tech', 'NNP'), 27),
#  (('place', 'NN'), 27),
#  (('touchscreen', 'NN'), 27),
#  (('sheet', 'NN'), 27),
#  (('waste', 'NN'), 27),
#  (('display', 'NN'), 27),
#  (('email', 'NN'), 26),
#  (('DO', 'NNP'), 26),
#  (('family', 'NN'), 26),
#  (('site', 'NN'), 26),
#  (('directions', 'NNS'), 26),
#  (('auto', 'NN'), 26),
#  (('party', 'NN'), 26),
#  (('labels', 'NNS'), 26),
#  (('ease', 'NN'), 26),
#  (('amount', 'NN'), 26),
#  (('level', 'NN'), 25),
#  (('PRINTER', 'NNP'), 25),
#  (('volume', 'NN'), 25),
#  (('parts', 'NNS'), 25),
#  (('interface', 'NN'), 25),
#  (('choice', 'NN'), 25),
#  (('messages', 'NNS'), 25),
#  (('Excellent', 'NNP'), 25),
#  (('cards', 'NNS'), 25),
#  (('results', 'NNS'), 25),
#  (('menu', 'NN'), 25),
#  (('complaint', 'NN'), 24),
#  (('copying', 'NN'), 24),
#  (('Smart', 'NNP'), 24),
#  (('matter', 'NN'), 24),
#  (('default', 'NN'), 24),
#  (('bottom', 'NN'), 24),
#  (('set-up', 'NN'), 24),
#  (('world', 'NN'), 24),
#  (('Was', 'NNP'), 24),
#  (('jet', 'NN'), 24),
#  (('crap', 'NN'), 24),
#  (('disc', 'NN'), 24),
#  (('papers', 'NNS'), 23),
#  (('B', 'NNP'), 23),
#  (('name', 'NN'), 23),
#  (('”', 'NN'), 23),
#  (('sides', 'NNS'), 23),
#  (('phones', 'NNS'), 23),
#  (('Scan', 'NNP'), 23),
#  (('update', 'NN'), 23),
#  (('AirPrint', 'NNP'), 23),
#  (('seconds', 'NNS'), 22),
#  (('plug', 'NN'), 22),
#  (('Ethernet', 'NNP'), 22),
#  (('range', 'NN'), 22),
#  (('W', 'NNP'), 22),
#  (('Did', 'NNP'), 22),
#  (('try', 'NN'), 22),
#  (('subscription', 'NN'), 22),
#  (('half', 'NN'), 22),
#  (('cell', 'NN'), 22),
#  (('Instant', 'NNP'), 22),
#  (('tank', 'NN'), 22),
#  (('functionality', 'NN'), 21),
#  (('addition', 'NN'), 21),
#  (('password', 'NN'), 21),
#  (('account', 'NN'), 21),
#  (('capabilities', 'NNS'), 21),
#  (('step', 'NN'), 21),
#  (('performance', 'NN'), 21),
#  (('heads', 'NNS'), 21),
#  (('Perfect', 'NNP'), 21),
#  (('connect', 'NN'), 21),
#  (('Do', 'NNP'), 21),
#  (('Photo', 'NNP'), 21),
#  (('list', 'NN'), 21),
#  (('usage', 'NN'), 21),
#  (('case', 'NN'), 20),
#  (('So', 'NNP'), 20),
#  (('frustration', 'NN'), 20),
#  (('description', 'NN'), 20),
#  (('past', 'NN'), 20),
#  (('App', 'NNP'), 20),
#  (('buy', 'NN'), 20),
#  (('TO', 'NNP'), 20),
#  (('minute', 'NN'), 20),
#  (('firmware', 'NN'), 20),
#  (('amazon', 'NN'), 20),
#  (('back', 'NN'), 19),
#  (('none', 'NN'), 19),
#  (('files', 'NNS'), 19),
#  (('husband', 'NN'), 19),
#  (('rating', 'NN'), 18),
#  (('info', 'NN'), 18),
#  (('luck', 'NN'), 18),
#  (('All-in-One', 'NNP'), 18),
#  (('Fast', 'NNP'), 18),
#  (('chance', 'NN'), 18),
#  (('hand', 'NN'), 18),
#  (('fast', 'NN'), 18),
#  (('delivery', 'NN'), 18),
#  (('Office', 'NNP'), 18),
#  (('Wi-Fi', 'NNP'), 18),
#  (('Don', 'NNP'), 18),
#  (('setting', 'NN'), 18),
#  (('right', 'NN'), 18),
#  (('complaints', 'NNS'), 18),
#  (('feels', 'NNS'), 18),
#  (('doesn', 'NN'), 18),
#  (('pack', 'NN'), 18),
#  (('technology', 'NN'), 18),
#  (('buttons', 'NNS'), 18),
#  (('store', 'NN'), 17),
#  (('items', 'NNS'), 17),
#  (('install', 'NN'), 17),
#  (('ones', 'NNS'), 17),
#  (('XL', 'NNP'), 17),
#  (('etc', 'NN'), 17),
#  (('Worst', 'NNP'), 17),
#  (('resolution', 'NN'), 17),
#  (('operation', 'NN'), 17),
#  (('Black', 'NNP'), 17),
#  (('rear', 'NN'), 17),
#  (('mistake', 'NN'), 16),
#  (('OS', 'NNP'), 16),
#  (('LAN', 'NNP'), 16),
#  (('Never', 'NNP'), 16),
#  (('Highly', 'NNP'), 16),
#  (('charm', 'NN'), 16),
#  (('upgrade', 'NN'), 16),
#  (('refill', 'NN'), 16),
#  (('“', 'NNP'), 16),
#  (('Scanner', 'NNP'), 16),
#  (('Product', 'NNP'), 16),
#  (('package', 'NN'), 16),
#  (('market', 'NN'), 16),
#  (('period', 'NN'), 16),
#  (('media', 'NNS'), 16),
#  (('TS9020', 'NNP'), 16),
#  (('smartphone', 'NN'), 15),
#  (('download', 'NN'), 15),
#  (('alignment', 'NN'), 15),
#  (('light', 'NN'), 15),
#  (('port', 'NN'), 15),
#  (('air', 'NN'), 15),
#  (('opinion', 'NN'), 15),
#  (('documentation', 'NN'), 15),
#  (('Super', 'NNP'), 15),
#  (('mine', 'NN'), 15),
#  (('hassle', 'NN'), 15),
#  (('letter', 'NN'), 15),
#  (('recommend', 'NN'), 15),
#  (('errors', 'NNS'), 15),
#  (('start', 'NN'), 15),
#  (('Android', 'NNP'), 15),
#  (('ADF', 'NNP'), 15),
#  (('fan', 'NN'), 15),
#  (('slot', 'NN'), 15),
#  (('’', 'NN'), 15),
#  (('avail', 'NN'), 15),
#  (('Amira', 'NN'), 15),
#  (('everyone', 'NN'), 14),
#  (('fine', 'NN'), 14),
#  (('Quality', 'NNP'), 14),
#  (('cover', 'NN'), 14),
#  (('prices', 'NNS'), 14),
#  (('easy', 'NN'), 14),
#  (('area', 'NN'), 14),
#  (('Envy', 'NNP'), 14),
#  (('storage', 'NN'), 14),
#  (('PDF', 'NNP'), 14),
#  (('change', 'NN'), 14),
#  (('nightmare', 'NN'), 14),
#  (('label', 'NN'), 14),
#  (('printer/scanner', 'NN'), 14),
#  (('floor', 'NN'), 14),
#  (('users', 'NNS'), 14),
#  (('machines', 'NNS'), 14),
#  (('Color', 'NNP'), 14),
#  (('refills', 'NNS'), 14),
#  (('call', 'NN'), 14),
#  (('cloud', 'NN'), 14),
#  (('trays', 'NNS'), 14),
#  (('load', 'NN'), 13),
#  (('MacBook', 'NNP'), 13),
#  (('reviewers', 'NNS'), 13),
#  (('Dell', 'NNP'), 13),
#  (('updates', 'NNS'), 13),
#  (('windows', 'NNS'), 13),
#  (('address', 'NN'), 13),
#  (('Had', 'NNP'), 13),
#  (('No', 'NNP'), 13),
#  (('equipment', 'NN'), 13),
#  (('LCD', 'NNP'), 13),
#  (('Have', 'NNP'), 13),
#  (('location', 'NN'), 13),
#  (('envelopes', 'NNS'), 13),
#  (('bunch', 'NN'), 13),
#  (('VERY', 'NNP'), 13),
#  (('levels', 'NNS'), 13),
#  (('supply', 'NN'), 13),
#  (('NO', 'NNP'), 13),
#  (('instruction', 'NN'), 13),
#  (('kids', 'NNS'), 13),
#  (('door', 'NN'), 13),
#  (('WIFI', 'NNP'), 13),
#  (('perfect', 'NN'), 13),
#  (('difference', 'NN'), 13),
#  (('all-in-one', 'NN'), 13),
#  (('solution', 'NN'), 13),
#  (('gift', 'NN'), 13),
#  (('sale', 'NN'), 13),
#  (('CD/DVD', 'NNP'), 13),
#  (('Printing', 'NN'), 12),
#  (('laptops', 'NNS'), 12),
#  (('Lexmark', 'NNP'), 12),
#  (('college', 'NN'), 12),
#  (('guy', 'NN'), 12),
#  (('flimsy', 'NN'), 12),
#  (('story', 'NN'), 12),
#  (('expectations', 'NNS'), 12),
#  (('fit', 'NN'), 12),
#  (('lemon', 'NN'), 12),
#  (('types', 'NNS'), 12),
#  (('PIXMA', 'NNP'), 12),
#  (('draft', 'NN'), 12),
#  (('Printer', 'NN'), 12),
#  (('wait', 'NN'), 12),
#  (('costs', 'NNS'), 12),
#  (('lack', 'NN'), 12),
#  (('Box', 'NNP'), 12),
#  (('file', 'NN'), 12),
#  (('Fax', 'NNP'), 12),
#  (('position', 'NN'), 12),
#  (('versions', 'NNS'), 12),
#  (('son', 'NN'), 12),
#  (('jams', 'NN'), 12),
#  (('AND', 'NNP'), 12),
#  (('min', 'NN'), 12),
#  (('memory', 'NN'), 12),
#  (('capacity', 'NN'), 12),
#  (('cameras', 'NNS'), 12),
#  (('Wifi', 'NNP'), 11),
#  (('faxes', 'NNS'), 11),
#  (('projects', 'NNS'), 11),
#  (('materials', 'NNS'), 11),
#  (('refund', 'NN'), 11),
#  (('Officejet', 'NNP'), 11),
#  (('student', 'NN'), 11),
#  (('disappointment', 'NN'), 11),
#  (('BUY', 'NNP'), 11),
#  (('friend', 'NN'), 11),
#  (('customers', 'NNS'), 11),
#  (('Jet', 'NNP'), 11),
#  (('“', 'NN'), 11),
#  (('spot', 'NN'), 11),
#  (('packaging', 'NN'), 11),
#  (('Thanks', 'NNS'), 11),
#  (('lines', 'NNS'), 11),
#  (('moment', 'NN'), 11),
#  (('BUT', 'NNP'), 11),
#  (('purpose', 'NN'), 11),
#  (('operating', 'NN'), 11),
#  (('jamming', 'NN'), 11),
#  (('trash', 'NN'), 11),
#  (('note', 'NN'), 11),
#  (('Christmas', 'NNP'), 11),
#  (('drive', 'NN'), 11),
#  (('wall', 'NN'), 11),
#  (('OK', 'NNP'), 11),
#  (('brands', 'NNS'), 11),
#  (('arm', 'NN'), 11),
#  (('multifunction', 'NN'), 11),
#  (('reasons', 'NNS'), 11),
#  (('warning', 'NN'), 11),
#  (('book', 'NN'), 11),
#  (('chat', 'NN'), 11),
#  (('noise', 'NN'), 11),
#  (('Customer', 'NNP'), 11),
#  (('Well', 'NNP'), 11),
#  (('offline', 'NN'), 11),
#  (('middle', 'NN'), 11),
#  (('glass', 'NN'), 11),
#  (('docs', 'NN'), 11),
#  (('connections', 'NNS'), 11),
#  (('SD', 'NNP'), 11),
#  (('register', 'NN'), 11),
#  (('purposes', 'NNS'), 10),
#  (('Buy', 'NNP'), 10),
#  (('term', 'NN'), 10),
#  (('wi-fi', 'NN'), 10),
#  (('Internet', 'NNP'), 10),
#  (('word', 'NN'), 10),
#  (('night', 'NN'), 10),
#  (('fits', 'NNS'), 10),
#  (('effort', 'NN'), 10),
#  (('Thank', 'NNP'), 10),
#  (('drawer', 'NN'), 10),
#  (('described', 'NN'), 10),
#  (('future', 'NN'), 10),
#  (('mind', 'NN'), 10),
#  (('shelf', 'NN'), 10),
#  (('Bought', 'NNP'), 10),
#  (('FAX', 'NNP'), 10),
#  (('Will', 'NNP'), 10),
#  (('POS', 'NNP'), 10),
#  (('Tried', 'NNP'), 10),
#  (('m', 'NNS'), 10),
#  (('questions', 'NNS'), 10),
#  (('joke', 'NN'), 10),
#  (('HPs', 'NNP'), 10),
#  (('rate', 'NN'), 10),
#  (('isn', 'NN'), 10),
#  (('bucks', 'NNS'), 10),
#  (('carts', 'NNS'), 10),
#  (('electronics', 'NNS'), 10),
#  (('fee', 'NN'), 10),
#  (('Software', 'NNP'), 10),
#  (('Chromebook', 'NNP'), 10),
#  (('ton', 'NN'), 10),
#  (('signal', 'NN'), 10),
#  (('decision', 'NN'), 10),
#  (('homework', 'NN'), 10),
#  (('sets', 'NNS'), 10),
#  (('pc', 'NN'), 10),
#  (('codes', 'NNS'), 10),
#  (('blue', 'NN'), 10),
#  (('disk', 'NN'), 10),
#  (('ve', 'NNS'), 10),
#  (('INK', 'NNP'), 10),
#  (('repair', 'NN'), 10),
#  (('apps', 'NN'), 9),
#  (('awhile', 'NN'), 9),
#  (('rest', 'NN'), 9),
#  (('workhorse', 'NN'), 9),
#  (('example', 'NN'), 9),
#  (('cd', 'NN'), 9),
#  (('pull', 'NN'), 9),
#  (('manufacturer', 'NN'), 9),
#  (('fix', 'NN'), 9),
#  (('Hp', 'NNP'), 9),
#  (('basis', 'NN'), 9),
#  (('x', 'NN'), 9),
#  (('application', 'NN'), 9),
#  (('yesterday', 'NN'), 9),
#  (('pieces', 'NNS'), 9),
#  (('average', 'NN'), 9),
#  (('holder', 'NN'), 9),
#  (('tape', 'NN'), 9),
#  (('tries', 'NNS'), 9),
#  (('configuration', 'NN'), 9),
#  (('hold', 'NN'), 9),
#  (('tasks', 'NNS'), 9),
#  (('troubleshooting', 'NN'), 9),
#  (('ethernet', 'NN'), 9),
#  (('date', 'NN'), 9),
#  (('stock', 'NN'), 9),
#  (('shame', 'NN'), 9),
#  (('Poor', 'NNP'), 9),
#  (('Too', 'NNP'), 9),
#  (('Use', 'NNP'), 9),
#  (('Instructions', 'NNS'), 9),
#  (('surprise', 'NN'), 9),
#  (('sales', 'NNS'), 9),
#  (('Drive', 'NNP'), 9),
#  (('question', 'NN'), 9),
#  (('headache', 'NN'), 9),
#  (('ALL', 'NNP'), 9),
#  (('feet', 'NNS'), 9),
#  (('Piece', 'NNP'), 9),
#  (('tablets', 'NNS'), 9),
#  (('seller', 'NN'), 9),
#  (('reset', 'NN'), 9),
#  (('PRINT', 'NNP'), 9),
#  (('trial', 'NN'), 9),
#  (('dollars', 'NNS'), 9),
#  (('manual', 'NN'), 9),
#  (('Touch', 'NNP'), 9),
#  (('Please', 'NNP'), 9),
#  (('run', 'NN'), 9),
#  (('cause', 'NN'), 9),
#  (('tax', 'NN'), 9),
#  (('Has', 'NNP'), 9),
#  (('cannon', 'NN'), 9),
#  (('pics', 'NNS'), 9),
#  (('weight', 'NN'), 9),
#  (('brother', 'NN'), 9),
#  (('Photos', 'NNP'), 9),
#  (('wire', 'NN'), 9),
#  (('love', 'NN'), 9),
#  (('XXL', 'NNP'), 9),
#  (('MX922', 'NNP'), 9),
#  (('discs', 'NN'), 9),
#  (('search', 'NN'), 8),
#  (('cyan', 'NN'), 8),
#  (('magenta', 'NN'), 8),
#  (('ream', 'NN'), 8),
#  (('reports', 'NNS'), 8),
#  (('status', 'NN'), 8),
#  (('Nothing', 'NN'), 8),
#  (('care', 'NN'), 8),
#  (('Error', 'NNP'), 8),
#  (('teacher', 'NN'), 8),
#  (('Everything', 'NNP'), 8),
#  (('Went', 'NNP'), 8),
#  (('Quality', 'NN'), 8),
#  (('IP', 'NNP'), 8),
#  (('failure', 'NN'), 8),
#  (('web', 'NN'), 8),
#  (('Again', 'NNP'), 8),
#  (('dust', 'NN'), 8),
#  (('result', 'NN'), 8),
#  (('data', 'NNS'), 8),
#  (('checks', 'NNS'), 8),
#  (('terms', 'NNS'), 8),
#  (('sense', 'NN'), 8),
#  (('cardstock', 'NN'), 8),
#  (('video', 'NN'), 8),
#  (('beginning', 'NN'), 8),
#  (('exception', 'NN'), 8),
#  (('living', 'NN'), 8),
#  (('mac', 'NN'), 8),
#  (('Installation', 'NNP'), 8),
#  (('HOURS', 'NNP'), 8),
#  (('Right', 'NNP'), 8),
#  (('Home', 'NNP'), 8),
#  (('google', 'NN'), 8),
#  (('Awesome', 'NNP'), 8),
#  (('con', 'NN'), 8),
#  (('worth', 'NN'), 8),
#  (('details', 'NNS'), 8),
#  (('daughter', 'NN'), 8),
#  (('services', 'NNS'), 8),
#  (('Which', 'NNP'), 8),
#  (('Airprint', 'NNP'), 8),
#  (('style', 'NN'), 8),
#  (('Ok', 'NNP'), 8),
#  (('Overall', 'NNP'), 8),
#  (('friends', 'NNS'), 8),
#  (('rollers', 'NNS'), 8),
#  (('folks', 'NNS'), 8),
#  (('carriage', 'NN'), 8),
#  (('fingers', 'NNS'), 8),
#  (('Wow', 'NNP'), 8),
#  (('Hopefully', 'NNP'), 8),
#  (('uses', 'NNS'), 8),
#  (('Always', 'NNP'), 8),
#  (('YOU', 'NNP'), 8),
#  (('flap', 'NN'), 8),
#  (('Got', 'NNP'), 8),
#  (('Prints', 'NNP'), 8),
#  (('cleaning', 'NN'), 8),
#  (('improvement', 'NN'), 8),
#  (('duplex', 'NN'), 8),
#  (('hopes', 'NNS'), 8),
#  (('Pretty', 'NNP'), 8),
#  (('inch', 'NN'), 8),
#  (('dozen', 'NN'), 8),
#  (('Image', 'NNP'), 8),
#  (('aftermarket', 'NN'), 8),
#  (('comparison', 'NN'), 8),
#  (('TS', 'NNP'), 8),
#  (('cassette', 'NN'), 8),
#  (('security', 'NN'), 7),
#  (('turn', 'NN'), 7),
#  (('iPhones', 'NNS'), 7),
#  (('GREAT', 'NNP'), 7),
#  (('faxing', 'NN'), 7),
#  (('means', 'NNS'), 7),
#  (('snap', 'NN'), 7),
#  (('photography', 'NN'), 7),
#  (('practice', 'NN'), 7),
#  (('project', 'NN'), 7),
#  (('doubt', 'NN'), 7),
#  (('communication', 'NN'), 7),
#  (('Pros', 'NNS'), 7),
#  (('experiences', 'NNS'), 7),
#  (('Inkjet', 'NNP'), 7),
#  (('construction', 'NN'), 7),
#  (('EASY', 'NNP'), 7),
#  (('Scans', 'NNPS'), 7),
#  (('replenishment', 'NN'), 7),
#  (('kinds', 'NNS'), 7),
#  (('bag', 'NN'), 7),
#  (('energy', 'NN'), 7),
#  (('prompts', 'NNS'), 7),
#  (('excellent', 'NN'), 7),
#  (('Print', 'NN'), 7),
#  (('utility', 'NN'), 7),
#  (('Time', 'NNP'), 7),
#  (('appearance', 'NN'), 7),
#  (('July', 'NNP'), 7),
#  (('hands', 'NNS'), 7),
#  (('cycle', 'NN'), 7),
#  (('recommendation', 'NN'), 7),
#  (('Haven', 'NNP'), 7),
#  (('longevity', 'NN'), 7),
#  (('Small', 'NNP'), 7),
#  (('budget', 'NN'), 7),
#  (('purchases', 'NNS'), 7),
#  (("N'T", 'NNP'), 7),
#  (('drawback', 'NN'), 7),
#  (('mins', 'NNS'), 7),
#  (('envelope', 'NN'), 7),
#  (('table', 'NN'), 7),
#  (('working', 'NN'), 7),
#  (('Friday', 'NNP'), 7),
#  (('Constantly', 'NNP'), 7),
#  (('section', 'NN'), 7),
#  (('printer.I', 'NN'), 7),
#  (('places', 'NNS'), 7),
#  (('companies', 'NNS'), 7),
#  (('heck', 'NN'), 7),
#  (('bar', 'NN'), 7),
#  (('sample', 'NN'), 7),
#  (('charge', 'NN'), 7),
#  (('screens', 'NNS'), 7),
#  (('play', 'NN'), 7),
#  (('simple', 'NN'), 7),
#  (('September', 'NNP'), 7),
#  (('morning', 'NN'), 7),
#  (('Laptop', 'NNP'), 7),
#  (('buying', 'NN'), 7),
#  (('tool', 'NN'), 7),
#  (('duty', 'NN'), 7),
#  (('August', 'NNP'), 7),
#  (('finger', 'NN'), 7),
#  (('components', 'NNS'), 7),
#  (('bed', 'NN'), 7),
#  (('areas', 'NNS'), 7),
#  (('state', 'NN'), 7),
#  (('profile', 'NN'), 7),
#  (('shot', 'NN'), 7),
#  (('plain', 'NN'), 7),
#  (('January', 'NNP'), 7),
#  (('Ive', 'NNP'), 7),
#  (('Doesn', 'NNP'), 7),
#  (('Price', 'NNP'), 7),
#  (('scam', 'NN'), 7),
#  (('Document', 'NNP'), 7),
#  (('CANON', 'NNP'), 7),
#  (('crazy', 'NN'), 7),
#  (('photographer', 'NN'), 7),
#  (('DVDs', 'NNP'), 7),
#  (('loader', 'NN'), 7),
#  (('Canon', 'NN'), 7),
#  (('photographs', 'NN'), 7),
#  (('difficulty', 'NN'), 7),
#  (('form', 'NN'), 7),
#  (('Pictures', 'NNS'), 7),
#  (('changes', 'NNS'), 6),
#  (('concern', 'NN'), 6),
#  (('Scanning', 'NNP'), 6),
#  (('smartphones', 'NNS'), 6),
#  (('/', 'NNP'), 6),
#  (('cases', 'NNS'), 6),
#  (('worthless', 'NN'), 6),
#  (('savvy', 'NN'), 6),
#  (('Took', 'NNP'), 6),
#  (('mess', 'NN'), 6),
#  (('REALLY', 'NNP'), 6),
#  (('Microsoft', 'NNP'), 6),
#  (('Catalina', 'NNP'), 6),
#  (('Simple', 'NNP'), 6),
#  (('length', 'NN'), 6),
#  (('slide', 'NN'), 6),
#  (('check', 'NN'), 6),
#  (('useless', 'NN'), 6),
#  (('None', 'NN'), 6),
#  (('reviews', 'NN'), 6),
#  (('Glad', 'NNP'), 6),
#  (('EVER', 'NNP'), 6),
#  (('link', 'NN'), 6),
#  (('mechanism', 'NN'), 6),
#  (('THE', 'NNP'), 6),
#  (('Printing', 'NNP'), 6),
#  (('Guess', 'NNP'), 6),
#  (('hrs', 'NN'), 6),
#  (('bonus', 'NN'), 6),
#  (('ANY', 'NNP'), 6),
#  (('hardware', 'NN'), 6),
#  (('All', 'NNP'), 6),
#  (('maintenance', 'NN'), 6),
#  (('library', 'NN'), 6),
#  (('Cartridges', 'NNS'), 6),
#  (('pattern', 'NN'), 6),
#  (('Quiet', 'NNP'), 6),
#  (('i', 'NNS'), 6),
#  (('YouTube', 'NNP'), 6),
#  (('words', 'NNS'), 6),
#  (('Walmart', 'NNP'), 6),
#  (('multi-function', 'NN'), 6),
#  (('AGAIN', 'NNP'), 6),
#  (('forever', 'NN'), 6),
#  (('environment', 'NN'), 6),
#  (('glad', 'NN'), 6),
#  (('strip', 'NN'), 6),
#  (('strength', 'NN'), 6),
#  (('orders', 'NNS'), 6),
#  (('convenient', 'NN'), 6),
#  (('stack', 'NN'), 6),
#  (('invoices', 'NNS'), 6),
#  (('gold', 'NN'), 6),
#  (('glitch', 'NN'), 6),
#  (('choices', 'NNS'), 6),
#  (('PC', 'NNP'), 6),
#  (('cabinet', 'NN'), 6),
#  (('go', 'NN'), 6),
#  (('figure', 'NN'), 6),
#  (('slow', 'NN'), 6),
#  (('selection', 'NN'), 6),
#  (('engineer', 'NN'), 6),
#  (('specs', 'NN'), 6),
#  (('frustrating', 'NN'), 6),
#  (('UI', 'NNP'), 6),
#  (('Word', 'NNP'), 6),
#  (('news', 'NN'), 6),
#  (('Update', 'NNP'), 6),
#  (('IOS', 'NNP'), 6),
#  (('iphone', 'NN'), 6),
#  (('replacements', 'NNS'), 6),
#  (('attempts', 'NNS'), 6),
#  (('horse', 'NN'), 6),
#  (('Air', 'NNP'), 6),
#  (('consumption', 'NN'), 6),
#  (('Sunday', 'NNP'), 6),
#  (('Ca', 'NNP'), 6),
#  (('s', 'NNS'), 6),
#  (('success', 'NN'), 6),
#  (('center', 'NN'), 6),
#  (('LOVE', 'NNP'), 6),
#  (('factor', 'NN'), 6),
#  (('rep', 'NN'), 6),
#  (('don', 'NN'), 6),
#  (('iMac', 'NN'), 6),
#  (('notch', 'NN'), 6),
#  (('breaker', 'NN'), 6),
#  (('icon', 'NN'), 6),
#  (('thinking', 'NN'), 6),
#  (('plus', 'NN'), 6),
#  (('input', 'NN'), 6),
#  (('attention', 'NN'), 6),
#  (('response', 'NN'), 6),
#  (('High', 'NNP'), 6),
#  (('UP', 'NNP'), 6),
#  (('Does', 'NNP'), 6),
#  (('XP', 'NNP'), 6),
#  (('colour', 'NN'), 6),
#  (('loss', 'NN'), 6),
#  (('generation', 'NN'), 6),
#  (('attempt', 'NN'), 6),
#  (('icons', 'NNS'), 6),
#  (('cheaply', 'NN'), 6),
#  (('Cloud', 'NNP'), 6),
#  (('applications', 'NNS'), 6),
#  (('DVD', 'NNP'), 6),
#  (('sizes', 'NNS'), 6),
#  (('CDs', 'NNS'), 6),
#  (('ghz', 'NN'), 6),
#  (('queue', 'NN'), 6),
#  (('Samsung', 'NNP'), 5),
#  (('brick', 'NN'), 5),
#  (('Everything', 'NN'), 5),
#  (('networks', 'NNS'), 5),
#  (('outlet', 'NN'), 5),
#  (('age', 'NN'), 5),
#  (('share', 'NN'), 5),
#  (('Monday', 'NNP'), 5),
#  (('beware', 'NN'), 5),
#  (('math', 'NN'), 5),
#  (('boxes', 'NNS'), 5),
#  (('stores', 'NNS'), 5),
#  (('mark', 'NN'), 5),
#  (('Thanks', 'NNP'), 5),
#  (('Jam', 'NNP'), 5),
#  (('crisp', 'NN'), 5),
#  (('buyers', 'NNS'), 5),
#  (('..', 'NN'), 5),
#  (('department', 'NN'), 5),
#  (('patience', 'NN'), 5),
#  (('tips', 'NNS'), 5),
#  (('orange', 'NN'), 5),
#  (('sucks', 'NNS'), 5),
#  (('bummer', 'NN'), 5),
#  (('yrs', 'NN'), 5),
#  (('press', 'NN'), 5),
#  (('Colors', 'NNS'), 5),
#  (('pdf', 'NN'), 5),
#  (('x', 'NNS'), 5),
#  (('format', 'NN'), 5),
#  (('graphics', 'NNS'), 5),
#  (('AWESOME', 'NNP'), 5),
#  (('action', 'NN'), 5),
#  (('get', 'NN'), 5),
#  (('Printers', 'NNP'), 5),
#  (('scanners', 'NNS'), 5),
#  (('epson', 'NN'), 5),
#  (('Copies', 'NNS'), 5),
#  (('User', 'NNP'), 5),
#  (('Spent', 'NNP'), 5),
#  (('spending', 'NN'), 5),
#  (('goodness', 'NN'), 5),
#  (('Add', 'NNP'), 5),
#  (('didn', 'NN'), 5),
#  (('controls', 'NNS'), 5),
#  (('Staples', 'NNP'), 5),
#  (('gon', 'NN'), 5),
#  (('OF', 'NNP'), 5),
#  (('FOR', 'NNP'), 5),
#  (('NEVER', 'NNP'), 5),
#  (('AFTER', 'NNP'), 5),
#  (('programs', 'NNS'), 5),
#  (('exit', 'NN'), 5),
#  (('AT', 'NNP'), 5),
#  (('assistant', 'NN'), 5),
#  (('T', 'NNP'), 5),
#  (('efficient', 'NN'), 5),
#  (('Ease', 'NNP'), 5),
#  (('dream', 'NN'), 5),
#  (('doc', 'NN'), 5),
#  (('w', 'NN'), 5),
#  (('modem', 'NN'), 5),
#  (('decades', 'NNS'), 5),
#  (('theory', 'NN'), 5),
#  (('faster', 'NN'), 5),
#  (('jets', 'NNS'), 5),
#  (('holes', 'NNS'), 5),
#  (('bedroom', 'NN'), 5),
#  (('zero', 'NN'), 5),
#  (('cumbersome', 'NN'), 5),
#  (('multi-page', 'NN'), 5),
#  (('printouts', 'NNS'), 5),
#  (('Windows', 'NNS'), 5),
#  ...]

# %%
tag_freq.plot(30)
